# %%
# !pip install google-api-python-client

# %%
import pandas
from googleapiclient.discovery import build
 
api_key = 'AIzaSyCJqGpIf0oJcS_hWKe8p1SM8w26KyrYGdQ'
video_id = 'E2pN3hXB8Pw'

comments = list()
api_obj = build('youtube', 'v3', developerKey=api_key)
response = api_obj.commentThreads().list(part='snippet,replies', videoId=video_id, maxResults=100).execute()
while response and len(comments) <= 100:
    for item in response['items']:
        comment = item['snippet']['topLevelComment']['snippet']
        comments.append([comment['textDisplay'], comment['authorDisplayName'], comment['publishedAt'], comment['likeCount']])
 
    if 'nextPageToken' in response:
        response = api_obj.commentThreads().list(part='snippet,replies', videoId=video_id, pageToken=response['nextPageToken'], maxResults=100).execute()
    else:
        break
 
df = pandas.DataFrame(comments, columns=['Comments','UserId','Date','LikeCount'])
print(len(df))
df.head()
# Out:
# {'kind': 'youtube#commentThreadListResponse', 'etag': '0WD5xXdaLzgU-5jhhrWZ30WKcYA', 'pageInfo': {'totalResults': 41, 'resultsPerPage': 100}, 'items': [{'kind': 'youtube#commentThread', 'etag': 'bUQLUYYdDSRYnNeyq7_DU_bxCqQ', 'id': 'UgwclNbO7fXuu87GEKV4AaABAg', 'snippet': {'videoId': 'E2pN3hXB8Pw', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'wd6CfUnAHTgfpP1CAIKDEfVk2E4', 'id': 'UgwclNbO7fXuu87GEKV4AaABAg', 'snippet': {'videoId': 'E2pN3hXB8Pw', 'textDisplay': '포스코 관련자들 무조건 구속', 'textOriginal': '포스코 관련자들 무조건 구속', 'authorDisplayName': '배수현', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQrkswIn2Lk8qhm4GVIoqleGrwzB19PK2bu-A=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCt4ncBxPpXzjBFR4kb8Yusw', 'authorChannelId': {'value': 'UCt4ncBxPpXzjBFR4kb8Yusw'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2022-06-26T04:31:30Z', 'updatedAt': '2022-06-26T04:38:05Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'ytZ_lDBU5LPdSNVsAWZ38vNl574', 'id': 'UgydOoJgexwV_u7n9RJ4AaABAg', 'snippet': {'videoId': 'E2pN3hXB8Pw', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'nG7KtDS1SYZ3sPyFu62Z-o0yqKM', 'id': 'UgydOoJgexwV_u7n9RJ4AaABAg', 'snippet': {'videoId': 'E2pN3hXB8Pw', 'textDisplay': '지 노동 시간은 완전 방탕하게 하면서 노동자들만 열심히 하라 ㅋㅋㅋ', 'textOriginal': '지 노동 시간은 완전 방탕하게 하면서 노동자들만 열심히 하라 ㅋㅋㅋ', 'authorDisplayName': 'st flux', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLT4juwxFrPy3K0UwVbYhK0EotKwUUbH6wS1CtRDog=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCBTe5LktHjGjfnsaIA2jErg', 'authorChannelId': {'value': 'UCBTe5LktHjGjfnsaIA2jErg'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2022-06-26T04:10:38Z', 'updatedAt': '2022-06-26T04:10:38Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'ab7OriPCRLC7AEb9atavRecyq40', 'id': 'UgzZWAagFWWhTrXWEmR4AaABAg', 'snippet': {'videoId': 'E2pN3hXB8Pw', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'AGs9hmePPvPX1u4NSefsooWOQlU', 'id': 'UgzZWAagFWWhTrXWEmR4AaABAg', 'snippet': {'videoId': 'E2pN3hXB8Pw', 'textDisplay': '에효! 제2의 박근혜 나왔네. 나몰랑? 지가  지시사항 이어서 장관이 직접 발표했는데 정부의 공식 입장이 아니다? ㅋ', 'textOriginal': '에효! 제2의 박근혜 나왔네. 나몰랑? 지가  지시사항 이어서 장관이 직접 발표했는데 정부의 공식 입장이 아니다? ㅋ', 'authorDisplayName': 'harkhyun lee', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLRMz9PiqmjUKAo8f8uZvoh2zg3IfjLZBwyscw=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UCB1wtAWeBbBOqEXnF0ZCpqQ', 'authorChannelId': {'value': 'UCB1wtAWeBbBOqEXnF0ZCpqQ'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 0, 'publishedAt': '2022-06-26T01:32:06Z', 'updatedAt': '2022-06-26T01:32:06Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'lyZNR33p_B_9eq-6ICiZmzg4VY0', 'id': 'UgyeIkG0B4JS-oQ1HsZ4AaABAg', 'snippet': {'videoId': 'E2pN3hXB8Pw', 'topLevelComment': {'kind': 'youtube#comment', 'etag': 'oS5zdxZsBaeAsm5pVlIp6A_yb4c', 'id': 'UgyeIkG0B4JS-oQ1HsZ4AaABAg', 'snippet': {'videoId': 'E2pN3hXB8Pw', 'textDisplay': '포스코 사건은 아마 소속 회사 직원들은 저걸 잘못.죄 라 생각하기보단 이래 여자는 안돼   겨우 그런걸로 회사를 시끄럽게 한다 ㅆ ㅂ 이럴걸?', 'textOriginal': '포스코 사건은 아마 소속 회사 직원들은 저걸 잘못.죄 라 생각하기보단 이래 여자는 안돼   겨우 그런걸로 회사를 시끄럽게 한다 ㅆ ㅂ 이럴걸?', 'authorDisplayName': 'Salome J', 'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AKedOLQXwUhbTKLGQ5zJOEtCHexOogxSPe2NJ0_Lbg=s48-c-k-c0x00ffffff-no-rj', 'authorChannelUrl': 'http://www.youtube.com/channel/UClYDUBR4kyBDjU5te1vSo0Q', 'authorChannelId': {'value': 'UClYDUBR4kyBDjU5te1vSo0Q'}, 'canRate': True, 'viewerRating': 'none', 'likeCount': 1, 'publishedAt': '2022-06-26T01:27:09Z', 'updatedAt': '2022-06-26T01:27:09Z'}}, 'canReply': True, 'totalReplyCount': 0, 'isPublic': True}}, {'kind': 'youtube#commentThread', 'etag': 'd7JtslcTLaS1A-7hRqm75IOJ7ds', 'id': 'UgywFQMk6uwXb_8OAhV4AaABAg', 'snippet' ...
# 41
#                                             Comments        UserId  \
# 0                                    포스코 관련자들 무조건 구속           배수현
# 1              지 노동 시간은 완전 방탕하게 하면서 노동자들만 열심히 하라 ㅋㅋㅋ       st flux
# 2  에효! 제2의 박근혜 나왔네. 나몰랑? 지가  지시사항 이어서 장관이 직접 발표했는...  harkhyun lee
# 3  포스코 사건은 아마 소속 회사 직원들은 저걸 잘못.죄 라 생각하기보단 이래 여자는 ...      Salome J
# 4  MBC뉴스 기자님들<br>사시느라 고생 많으십니다 사랑합니다 💜 항상국민의행복을위해...           정범수
#
#                    Date  LikeCount
# 0  2022-06-26T04:31:30Z          0
# 1  2022-06-26T04:10:38Z          0
# 2  2022-06-26T01:32:06Z          0
# 3  2022-06-26T01:27:09Z          1
# 4  2022-06-26T00:07:49Z          0

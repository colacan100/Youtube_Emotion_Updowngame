# %%
# !pip install google-api-python-client

# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
api_key = 'AIzaSyCJqGpIf0oJcS_hWKe8p1SM8w26KyrYGdQ'
youtube = build('youtube', 'v3', developerKey=api_key)

movie_name = '신과함께-죄와 벌'
add_name = '메인 예고편'

# 제일 관련성 있는 항목 1개
search_response = youtube.search().list(
    q = movie_name+add_name,
    order = "relevance",    # 관련성 순으로 정렬
    part = "snippet",       # 영상 정보
    regionCode = 'kr',      # 한국
    maxResults = 1          # 검색수
    ).execute()
search_response
# Out:
# {'etag': 'RJ-sok8KwV7L9VlKf7OVwiKqKU8',
#  'items': [{'etag': 'A3mqTdZMEafnHl06t7NUlC41CNw',
#    'id': {'kind': 'youtube#video', 'videoId': '5O5PVvHTWRo'},
#    'kind': 'youtube#searchResult',
#    'snippet': {'channelId': 'UCC2F35lZ0drUeMJOATXde2g',
#     'channelTitle': '롯데엔터테인먼트',
#     'description': "아무도 본 적 없는 세계와의 만남! 49일 동안 벌어지는 7개의 재판이 시작된다! '신과함께-죄와 벌'메인 예고편 공개!",
#     'liveBroadcastContent': 'none',
#     'publishTime': '2017-11-24T00:48:57Z',
#     'publishedAt': '2017-11-24T00:48:57Z',
#     'thumbnails': {'default': {'height': 90,
#       'url': 'https://i.ytimg.com/vi/5O5PVvHTWRo/default.jpg',
#       'width': 120},
#      'high': {'height': 360,
#       'url': 'https://i.ytimg.com/vi/5O5PVvHTWRo/hqdefault.jpg',
#       'width': 480},
#      'medium': {'height': 180,
#       'url': 'https://i.ytimg.com/vi/5O5PVvHTWRo/mqdefault.jpg',
#       'width': 320}},
#     'title': '[신과함께-죄와 벌] 메인 예고편'}}],
#  'kind': 'youtube#searchListResponse',
#  'nextPageToken': 'CAEQAA',
#  'pageInfo': {'resultsPerPage': 1, 'totalResults': 13116},
#  'regionCode': 'KR'}

# %%
video_id = search_response['items'][0]['id']['videoId']
video_id
# Out:
# '5O5PVvHTWRo'

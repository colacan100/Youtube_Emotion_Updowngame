# %%
# 외부 IP 확인하기

import requests

print(requests.get("http://ip.jsontest.com").json()['ip'])
# Out:
# 35.227.157.253

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### DB 적재

# %%
# DB 연결
from pymongo import MongoClient

client = MongoClient(host='3.37.202.252', port=27017)

# %%
print(client.list_database_names())
# Out:
# ['admin', 'config', 'local', 'youtube_comment_database']

# %%
# Collection 접근
db = client['youtube_comment_database']
collection = db['youtube_comment_collection']

# %%
import json
a_json = open('/content/drive/MyDrive/add_comments_data.json', encoding='utf-8')
a_dict = json.load(a_json)

# %%
collection.insert_one(document=a_dict)

# %% [markdown]
# ---
# ### Modeling

# %%
import pandas as pd
import urllib.request
import json
import numpy as np
import re
import os
import sys
import collections
import tensorflow as tf 

from keras import *
from keras.layers import *
from tensorflow.keras.utils import to_categorical
from tensorflow import keras
from bpemb import BPEmb

# %%
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt", filename="ratings_train.txt")
urllib.request.urlretrieve("https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt", filename="ratings_test.txt")
# Out:
# ('ratings_test.txt', <http.client.HTTPMessage at 0x7f8fc305fc90>)

# %%
train_data = pd.read_csv('ratings_train.txt', sep='\t').dropna()
test_data = pd.read_csv('ratings_test.txt', sep='\t').dropna()

# column 이름 변경 
train_data.rename(columns = {'document' : 'review'}, inplace = True)
test_data.rename(columns = {'document' : 'review'}, inplace = True)

# csv 파일로 저장
train_data.to_csv('train_data.csv', index=False)
test_data.to_csv('test_data.csv', index=False)

# %%
d_emb = 300
vocab_size = 200000
batch_size = 128
seq_max = 200

# %%
TRAIN_DIR = './ratings_train.txt'
TEST_DIR = './ratings_test.txt'

# %%
# 참이면 사전 훈련된 벡터로 가중치 포함 초기화 
pre_trained = True

# True이면 4 CNN 레이어 사용
quad_layer = True

filter_size = 100

if quad_layer:
  windows = [2, 3, 4, 5]
else: 
  windows = [2, 3, 4]

# %%
if pre_trained:
    bpemb_ko = BPEmb(lang="ko", dim=d_emb, vs=vocab_size) 
else:
    bpemb_ko = BPEmb(lang="ko", vs=vocab_size)
# Out:
# downloading https://nlp.h-its.org/bpemb/ko/ko.wiki.bpe.vs200000.model
# 100%|██████████| 4234933/4234933 [00:01<00:00, 3702894.57B/s]
# downloading https://nlp.h-its.org/bpemb/ko/ko.wiki.bpe.vs200000.d300.w2v.bin.tar.gz
# 100%|██████████| 224212701/224212701 [00:13<00:00, 16724103.27B/s]

# %%
def parsing(data):
    first_t = data.find('\t')
    second_t = data[first_t + 1:].find('\t') + first_t + 1
    _id = data[:first_t]
    document = data[first_t + 1:second_t]
    label = data[second_t + 1:]
    
    return _id, document, label

# %%
def add_padding(arr, max_len):
    results = []
    for tmp in arr:
        for i in range(len(tmp), max_len):
            tmp.append(0)
        results.append(tmp)

    return results

# %%
def raw_to_data(raw):
    x = []
    y = []
    for data in raw[1:]:

        _, document, label = parsing(data)

        tmp = bpemb_ko.encode_ids(document)

        if seq_max < len(tmp):
            continue

        if len(tmp) == 0:
            continue
    
        x.append(tmp)
        y.append(label)
        
    return np.array(add_padding(x.copy(), seq_max)), to_categorical(np.array(y.copy(), dtype='int32'))

# %%
with open(TRAIN_DIR, "r", encoding='utf8') as f:
    train_raw_data = f.readlines()

# %%
with open(TEST_DIR, "r", encoding='utf8') as f:
    test_raw_data = f.readlines()

# %%
x_train, y_train = raw_to_data(train_raw_data)
x_test, y_test = raw_to_data(test_raw_data)

print('x_train shape: ', x_train.shape)
print('y_train shape: ', y_train.shape)
print('x_test shape: ', x_test.shape)
print('y_test shape: ', y_test.shape)
# Out:
# x_train shape:  (149995, 200)
# y_train shape:  (149995, 2)
# x_test shape:  (49997, 200)
# y_test shape:  (49997, 2)

# %%
class SentimentalCNN:
    def __init__(self, vocab_size, d_emb, seq_max, weight=None, trainable=False):

        if weight is None:
            self.emb_layer = Embedding(vocab_size, d_emb, input_length=seq_max)
            
        else:
            self.emb_layer = Embedding(vocab_size, d_emb, input_length=seq_max, weights=[weight], trainable=trainable)

            self.reshape_layer = Reshape((seq_max, d_emb, 1), input_shape=(seq_max, d_emb)) 
            
            self.bi_cnn = Conv2D(filter_size * 1, kernel_size=(windows[0], d_emb), activation='relu', input_shape=(seq_max, d_emb, 1))
            self.tri_cnn = Conv2D(filter_size * 1, kernel_size=(windows[1], d_emb), activation='relu', input_shape=(seq_max, d_emb, 1))
            self.quad_cnn = Conv2D(filter_size * 1, kernel_size=(windows[2], d_emb), activation='relu', input_shape=(seq_max, d_emb, 1))
            
            if quad_layer:
                self.penta_cnn = Conv2D(filter_size * 1, kernel_size=(windows[3], d_emb), activation='relu', input_shape=(seq_max, d_emb, 1))
                
            self.output_layer = Dense(2, activation='softmax')

    def compile(self, optimizer="adam"):
        _input = Input(shape=(None, ), dtype='int32')

        emb = self.emb_layer(_input)
        reshape_emb = self.reshape_layer(emb)
            
        bi_res = self.bi_cnn(reshape_emb)
        tri_res = self.tri_cnn(reshape_emb)
        quad_res = self.quad_cnn(reshape_emb)
            
        bi_res = Dropout(0.3)(bi_res)
        tri_res = Dropout(0.3)(tri_res)
        quad_res = Dropout(0.3)(quad_res)
                
        a = MaxPool2D(pool_size=(seq_max - windows[0] - 1, 1))(bi_res)
        b = MaxPool2D(pool_size=(seq_max - windows[1] - 1, 1))(tri_res)
        c = MaxPool2D(pool_size=(seq_max - windows[2] - 1, 1))(quad_res)
            
        if quad_layer:
            penta_res = self.penta_cnn(reshape_emb)
            penta_res = Dropout(0.3)(penta_res)
            d = MaxPool2D(pool_size=(seq_max - windows[3] - 1, 1))(penta_res)
            result = Concatenate(axis=-1)([a, b, c, d])
            
        else:
            result = Concatenate(axis=-1)([a, b, c])
                
        result = Flatten()(result)
        result = self.output_layer(result)

        self.model = Model(_input, result)
        self.model.compile(
            loss='categorical_crossentropy',
            optimizer=optimizer,
            metrics=['accuracy']
        )
            
    def predict(self, _input):
        x = bpemb_ko.encode_ids(_input)
        x = np.array(add_padding([x], seq_max))
                    
        res = self.model.predict(x)
                
        if res[0][0] < res[0][1]:
            print(_input + "\n: 긍정")
                    
        else:
            print(_input + "\n: 부정")

# %%
if pre_trained:
    sent_cnn = SentimentalCNN(
        vocab_size=vocab_size,
        d_emb=d_emb,
        seq_max=seq_max,
        weight=bpemb_ko.vectors,
        trainable=True
    )
            
else:
    sent_cnn = SentimentalCNN(
        vocab_size=vocab_size,
        d_emb=d_emb,
        seq_max=seq_max
    )

    
sent_cnn.compile(tf.optimizers.Adam(lr=0.001, decay=1e-6))
sent_cnn.model.build(input_shape=(seq_max, ))
sent_cnn.model.summary()
hist = sent_cnn.model.fit(x_train, y_train,
                          epochs=3,
                          batch_size=batch_size,
                          verbose=1,
                          validation_data=(x_test, y_test))
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/adam.py:105: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None)]       0           []
#
#  embedding (Embedding)          (None, None, 300)    60000000    ['input_1[0][0]']
#
#  reshape (Reshape)              (None, 200, 300, 1)  0           ['embedding[0][0]']
#
#  conv2d (Conv2D)                (None, 199, 1, 100)  60100       ['reshape[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 198, 1, 100)  90100       ['reshape[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 197, 1, 100)  120100      ['reshape[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 196, 1, 100)  150100      ['reshape[0][0]']
#
#  dropout (Dropout)              (None, 199, 1, 100)  0           ['conv2d[0][0]']
#
#  dropout_1 (Dropout)            (None, 198, 1, 100)  0           ['conv2d_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 197, 1, 100)  0           ['conv2d_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 196, 1, 100)  0           ['conv2d_3[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 1, 1, 100)    0           ['dropout[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 1, 1, 100)   0           ['dropout_1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 1, 1, 100)   0           ['dropout_2[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 1, 1, 100)   0           ['dropout_3[0][0]']
#
#  concatenate (Concatenate)      (None, 1, 1, 400)    0           ['max_pooling2d[0][0]',
#                                                                   'max_pooling2d_1[0][0]',
#                                                                   'max_pooling2d_2[0][0]',
#                                                                   'max_pooling2d_3[0][0]']
#
#  flatten (Flatten)              (None, 400)          0           ['concatenate[0][0]']
#
#  dense (Dense)                  (None, 2)            802         ['flatten[0][0]']
#
# ==================================================================================================
# Total params: 60,421,202
# Trainable params: 60,421,202
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/3
# 1172/1172 [==============================] - 3670s 3s/step - loss: 0.3749 - accuracy: 0.8331 - val_loss: 0.3363 - val_accuracy: 0.8576
# Epoch 2/3
# 1172/1172 [==============================] - 3694s 3s/step - loss: 0.2517 - accuracy: 0.8985 - val_loss: 0.3277 - val_accuracy: 0.8597
# Epoch 3/3
# 1172/1172 [==============================] - 3691s 3s/step - loss: 0.1664 - accuracy: 0.9370 - val_loss: 0.3688 - val_accuracy: 0.8540

# %% [markdown]
# ---
# ### 감정 분석

# %%
post_id_1 = str('62c3d51d0150cc08b72e4368') # video_comments
post_id_2 = str('62c3c0441138d063a9b71e3b') # video_info

# %%
from bson.objectid import ObjectId
video_comments_bson_id = ObjectId(post_id_1)
video_comments = collection.find_one({"_id": video_comments_bson_id})
video_info_bson_id = ObjectId(post_id_2)
video_info = collection.find_one({"_id": video_info_bson_id})

# %%
del video_comments['_id']
del video_info['_id']

# %%
## video_comments 재구성
for movie_name in  video_info:
    video_comments[movie_name] = video_comments[movie_name]['Comments']

# %%
import pandas as pd

def pad_dict_list(dict_list, padel=''):
    lmax = 0
    for lname in dict_list.keys():
        lmax = max(lmax, len(dict_list[lname]))
    for lname in dict_list.keys():
        ll = len(dict_list[lname])
        if  ll < lmax:
            dict_list[lname] += [padel] * (lmax - ll)
    return dict_list

video_comments = pad_dict_list(video_comments)
df = pd.DataFrame(video_comments)

# %%
reviews = df['명량 '].to_list()

for sen in reviews:
  result = sent_cnn.predict(sen)
# Out:
# 이순신장군님 감사합니다
# : 긍정
# 한산대첩에서 당한 기억 때문에 대장선 하나만 나와있는 것도 무슨 작전인 줄 아는 거 디테일하네
# : 부정
# 포에 미친 민족
# : 부정
# 난중일기는 꼭 읽어보시고 다시한번 충무공께 감사하시기 바랍니다 우린 충무공이 아니였다면 혼다나 나까지마가 되었을 것입니다
# : 긍정
# 이거 보고 국뽕에 취할려고 하는데 추천영화가 악마를 보았다로 연결되네
# : 긍정
# 그 누구도 이순신 장군님께 모욕댓글 쓰지마라 늬들이 그시대 살았어 국가에 충성이란 무슨 의미를 아나 일본 압잡이 도맡아서 할놈들 좋은글 에 꼭 이상한넘들 이씀 그넘들은 미친넘 병쉰같은 넘들이지 아순신장군님덕에 이시대 내가 있는거임
# : 부정
# 못보겠는거 억지 백병전 까마귀절규 나룻배 레카
# : 부정
# 참 명 감독에 명배우들의 열연이었습니다 최민식이란 배우의 연기력은 많은 대사가 없이도 정말 잘 소화해 내는 진짜 명배우네요
# : 긍정
# 필요없는 신파장면 이순신을 빼면 나머지 인물들이 병풍인 영화 다만 최민식의 연기가 빛남
# : 부정
# 오와우
# : 긍정
# 스님들 쎄다
# : 부정
# 개쌉노잼
# : 부정
# 스님이 왜 전투를 해요
# : 긍정
# 명량이 이래서 욕먹었구나 영화자체는 재미있지만 실제 명량대첩은 이순신성웅이 탑승한 대장선 한척으로 쓸어버렸고 공식적인 사망자는 명임 그냥 능욕 그 자체였음 롤로 치자면 페이커 초급봇 이정도 차이
# : 긍정
# 이순신장군이 살아 돌아오셔서 주옥순 같은 토왜들이 한국에 바글바글 한 거 보면 뭐라 하실까 진짜 모조리 칼로 베어버리겠지
# : 부정
# 실화라는게 어이가 없음 고구려 전투 스파르타 테르모필레협곡전투 이순신 해상전 진짜 어이가 없음 말도 안되는 스토리라
# : 부정
# 아시박 눈물나
# : 긍정
# 개 같은 전라도 내로남불 정권이 국민 뒷통수 치려고 만든 영화
# : 부정
# 두번 다시는 나라를 빼기는일은 없을거다 정신차려라
# : 부정
# 물론 고증이 아쉬운 건 사실이지만 고증만으로 영화를 볼 거면 그 사람들은 영화관이 아니라 집에서 다큐를 보는 게 맞다고 생각한다 내용면에서 비판하면 몰라도 고증만으로 물고 늘어지는 사람들은 학창시절 자랑할 거리고는 역사 점수 높은 것 밖에 없는 역사충일 확률이
# : 긍정
# 비록 선조가 암군이긴 하나 학식이 짧거나 모자란 인물은 아님 당시 이순신을 파격승진 시킨것과 어벤져스 관료를 등용한것도 다 선조의 안목이 있었기에 가능했던일 다만 그놈의 방계출신 컴플렉스 때문에 끊임없이 의심하고 견제하는데 온 신경을 쓰다보니 저 꼬라지가 난거 만약 선조가 적장자였다면 이순신을 질투하지도 않았을거고 원균 대신 끝까지 그를 믿고 등용했을거다 참 어찌보면 안타까운 왕 중의 한명이 선조가 아닐런지 분명 정치력이나 머리는 똑똑한 인물인데 그놈의
# : 긍정
# 전쟁과 평화
# : 긍정
# 고독하고 외로운 장군 하지만신념과 자신을 따르는 부하 본인이 나라를위해 할수있는 노력을 늙을때까지 성심꺼 열심히한 장군
# : 긍정
# 이순신 수염색을 보니 너무 늙었네 요즘 같으면 군 면제
# : 부정
# 이순신 장구님 나라를지켜줘셔서 감사합니다
# : 긍정
# 항상 알아야할 사실이 옛날부터 이 나라는 썩어빠진 고위간부들이 살린게 아니라 사명감을 가지고 맡은바 임무를 완수했던 몇안되는 명장들과 백성들이 살린나라죠
# : 긍정
# 지금 그대로 본다면 충무공 이순신 장군은 해전의 신이라고 보는게 맞음
# : 부정
# 솔직히 난 영화가 재밌지는 않았는데 평이 너무 좋았음
# : 긍정
# 분 초에 대사는 결국 몰살당하는것은 저녀석들 쪽이다 입니다 물살이나 우리편같은 일본어대사는 없습니다 그리고 물의 흐름은 우리쪽으로 기울고 있다 입니다
# : 긍정
# 이 한분이 아니었으면 오늘을사는 우리가 한국인의 피를가지고 일본 국적으로 태어날 수도 있었지요 단지 영웅이 아니라 성웅 맞습니다
# : 긍정
# 그리고 척이였으나 김억추는 제일 맨 뒤에 그리고 척은 일자진 대장선 한척만 시간동안 무쌍하시고 나중에 척이 지원 물살 바뀌고 나머지 참전임 명량은 충무공 혼자서 만든 전설임 한산은 지원병력이 있었으나 명량은 그냥 대 척임 그리고 대 척이라는 설도 있지만 해전중 까부신게 척이고 왜 선박이 척
# : 부정
# 명량이 이정도인데 한산 노량은 어우 충무공은 음 형용할 수 없는 위인이지만 그 자손중에 권율 후손과 덕수이씨 여성이 낳은 권중현이라고 을사오적이 있다
# : 부정
# 센세니 카와이니 히메니 이상한말 쓰지말자
# : 긍정
# 이순신 장군은 마블영화 스토리의 주인공이 아니라 실제 존재했던 영웅입니다 정말 대단합니다
# : 긍정
# 현측에 무장한 함선 척 보병수송함 척
# : 부정
# 이정현이 역할을 했던 치마를 벗어 흔들었던 말 못하는 여인네가 너무 가슴 아팠지
# : 긍정
# 일본에서 욕 먹으며 일하며 수도 없이 때려치우고 한국 가서 살고 싶어지지만 이 영상을 보며 마음을 달래며 나 자신이 부끄러워지고 또 한편으론 위안도 받습니다 자랑스럽고 존경합니다 이순신 장군님
# : 긍정
# 그 와중에 순신 장군님 말 듣고 따라준 병사님드류
# : 부정
# 이거 살고자 하면 죽을 것이다 죽고자하면 살 것이다 동생한테 보여줬더니 형 그러면 이순신 장군님은 살고자 해서 죽은거야 라고해서 어이가 없었음
# : 부정
# 볼 때마다 감동과 눈물입니다 항상 늘 언제나 존경합니다
# : 긍정
# 한산 용의출현 아주 기대가 됩니다
# : 부정
# 난 이 분 연기가 참 인상깊고 마음에 들었음 정말 조선의 장수 같았어
# : 긍정
# 명량해전 당시 배의 수가 수십배 이상 차이가 났는데도 불구하고 잘 이끄러주신 이순신 장군님께 감사를 드립니다 그리고 그 당시 전투하신 분들께 감사드립니다
# : 긍정
# 영화에선 와키자카 야스하루가 찌질하게 나왔지만 사실 일본 해적들 모조리 소탕하고 전술의 천재로 히데요시 왼쪽에 있던 대단한 장수인데 갓순신 장군님 만나서
# : 긍정
# 최악의 노잼 영화 영화보다가 잤던건 명량이 처음
# : 부정
# 이순신 장군님 자랑스럽고 그런건 맞는데 댓글들은 뭔 눈물이 차오르고 그러냐 나만 이해안돠고 오그라드냐 영화는 찐천만이지 이딴 영화를 두번 본 사람은 없을테니 진짜 국뽕 개웃기네
# : 부정
# 류승룡 목잘려서 걸렸을때 속이 다 시원했다
# : 긍정
# 박혜일이 잘할수 있을까
# : 긍정
# 원래 한국영화는 냄새나서 못보겟는데 정말 유일해도 너무 유일하게 영화관에서 안보고 후회하는영화는 명량딱하나뿐 기생충은커녕 번방의선물 극한직업 도둑들 타짜조차 재밋게본적 하나도없는데 명량만 딱 유일하게 정말재밋게봣음
# : 부정
# 이 정도면 도 아님 그냥 킹그레이트갓엠페러제네럴충무공 이순신 장군님의 원맨쇼
# : 부정
# 근데 왜 불법 의혹자들이 판치는 오늘날의 대한민국이 되었냐 짜장면이 그리 맛있냐
# : 부정
# 일본장군 등 장 일본장군 등장 초만에 사 망 대 가 리
# : 긍정
# 극적인 장치를 너무 많이 써서 필요없는 컷을 남발해서 아쉬웠던 인물들 대사랑 절체절명의 상황에 더 장면을 많이 할애했다면 명량해전의 전투의 의미가 더 깊게 다가왔을텐데
# : 긍정
# 역사 그대로 만들면 너무 말도 안 되게 압도적이라 이순신을 너프시킨 영화 세종대왕과 더불어 가장 존경받는 위인이라 연구도 많이 이루어졌는데요 학자들이 단점을 찾을래야 찾을 수가 없었다더군요 굳이 찾는다면 어릴 때 골목대장 노릇하면서 자기 영역을 침범한 어른에게 활을 겨누려 했던거나 참외를 안 준다고 말을 몰고와서 참외밭을 망친 것 등의 소소한 이야기들 뿐 이순신 일진설
# : 긍정
# 명량 참 부족한 영화라고 생각합니다 그냥 액션 영화일 뿐 이순신 장군님의 위대함과 명석함은 전혀 안 보이는 영화 이순신 장군의 승리도 운 단순 임전무퇴 정신으로 이겼다고 보여지게 만든 점이 참 아쉽 그리고 가장 아쉬운 장면은 넘어가는 배를 백성들이 일으켜세우는 장면 진짜 개어이없었음
# : 부정
# 주모
# : 부정
# 이정현 절벽탈때 눈빛연기 진심 집중력대박
# : 긍정
# 민초의 역사
# : 긍정
# 국뽕을 표현한 영화 이순신 대단한거 모르는 사람 없지만 과도한건 너무 싫다 한국영화에서 제일 싫은건 국뽕과 신파다 하지만 흥행보증수표는 국뽕과 신파다 난 한국드라마도 시트콤만 본다 그래야 극단적인 감정이 없기 때문
# : 부정
# 역시 활의민족
# : 긍정
# 육지엔권율해양앤이순신장군님 정말감사합니다
# : 긍정
# 척 가지고 싸웠네 척 가지고 싸웠네 가지고 말이 많은데 사실은 척 가지고 싸운거지 척 가지고도 안 깨지고 버티니까 나머지 배들이 도우러 온 거고 그래봤자 척 척이었지만
# : 부정
# 좀 솔직하자 최민식이가 성웅 이순심장군의 역활로 적합하냐 최민식은 그냥 전장터에 나간 돼지로 밖에 안보인다
# : 부정
# 스타로 치면 시즈탱크 한대로 저글링 부대 다 쓸어낸 미친기록 이게 실제 역사였다는게 놀라울뿐이다
# : 긍정
# 귀인은 시대를 가리지 않고 나타난다
# : 부정
# 진중권이 명량 졸작이라고 깠지
# : 부정
# 난 여기가 좋드라
# : 긍정
# 군신 이순신
# : 긍정
# 눈물이 난다
# : 긍정
# 최민식은 말했지 명량은 핫도그가 존맛탱이라고
# : 긍정
# 아무리 극적인 역사라도 연출한 영화처럼 극적일 수 없겠지만 이순신 장군의 일생과 매 전투는 영화가 아마 현실보다 덜 극적일 것 같다는 생각이 든다
# : 긍정
# 아무리 극적인 역사라도 연출한 영화처럼 극적일 수 없겠지만 이순신 장군의 일생과 매 전투는 영화로 그린게 아마 현실보다 덜 극적일 것 같다는 생각이 든다
# : 긍정
# 다시또봐도 감동적입니다 최민식 배우님도 연기를 너무잘하셔서 볼때마다 웁니다
# : 긍정
# 이순신 장군님진짜대단하다
# : 긍정
# 급 물 속성 대한민국 수호신
# : 긍정
# 이순신 관련 자료나 평가에서 제일 이순신에 비판적인 자료는 난중일기밖에 없다는게 충격임
# : 부정
# 어흑흑 너무 멋있어
# : 긍정
# 명량 매번볼때마다 감동입니다 감사 합니다 장군님
# : 긍정
# 우리 외할아버지의 아버지의 아버지의 아버지의 아버지의 아버지의 아버지 이 정도면 되나 하여튼 그려 감사합니다 이순신 장군님
# : 긍정
# 척 이건 잘못된 역사 척이 맞다 그냥 이순신 기함 혼자 싸운거나 마찬가지 이래서 이순신이 전장의 신이란 별명이 생긴거
# : 부정
# 불멸 드라마는 척인데 영화에서는 척 어떤것이 맞을까요 드라마와는 좀 다른게 있긴하네요
# : 부정
# 역사 적으로 볼때 왜적 당적 침략으로 보면 전부 전라도가 지키고 경상도 신라는 나라 파라 먹고 지금도 경상도는 석열이 찍고 경상도 벼신들
# : 부정
# 고증이니 국뽕이니 뭐 한편으론 말 많은 영화였지만 그래도 입장 바꿔서 생각해 보면 어쩔 수 없는 처사였다고 생각합니다 왜냐하면 실제 역사는 더 말이 안되고 영화도 이렇게 만들면 욕 먹을 정도니까요 저는 공부하면서 왜구들 좀 커엽네 라고 생각도 했었는데 해군 한정 그 만큼 거의 일방적인 학살극 장군님의 일진놀이 한거라 조금 극적임을 더하기 위한 영화적 허용 정도로 이해해 주시고 즐겨 주셨으면 좋겠네요 그 만큼 장군님이 대단 하셨음은 틀림 없는 고증이니까요
# : 긍정
# 카메라 무빙이랑 침 튀기는거 진짜 예술이다
# : 부정
# 언월도 스님 짱
# : 긍정
# 이것이 코리아다
# : 긍정
# 이슌신 하고 화살맞고 머리잘리러왔냐 한거아무것도없음 진구가 멋있게 전사 임자 먼저 가네
# : 긍정
# 된다고 말하게 라고 할떄 진짜 끓어오름
# : 긍정
# 소름과 오글거림이 공존했던 영화 전투씬은 소름 백성의 반응 전투 중 몇몇 연출은 오글
# : 부정
# 김명수배우님을 일본무사로 출연시키지 와키자카
# : 부정
# 갑옷 고증이 너무 중국풍이라 아쉬웠음 그리고 척이 모두 전투선이다 척만 전투선이다 말이 많지만 그럼에도 척으로 막은건 정말 훌륭한 전과 그럼에도 한달도 안돼서 수도가 함락된 조선은 정말 개병신
# : 부정
# 우리가 장군의 후손이라는 사실이 그저 자랑스럽습니다
# : 긍정
# 이순신 장군님도 그 수하의 많은 부하 장수분들도 이름이 알려지지 않는 많은 병사분들도 저때 얼마나 두려우셨을까 감사합니다 그저 감사합니다
# : 긍정
# 일본장수 에게 쪼꼼한게 까불고 있어
# : 부정
# 꼬시다 꼬셔
# : 부정
# 충무공 이순신장군이면 국뽕 치사량까지 빨아도 유익하잖아요
# : 부정
# 아니야 이순신의 키는 의 작은 키의 비쩍 마른 몸매였어
# : 긍정
# 전설을 넘어 신이 되신 분
# : 긍정
# 더 단결될수 있던게 쇄국 정책 때문일수도 있다고 생각되네 공산주의 사회주의 보면 물론 공산이 좋다는건 아니고
# : 긍정
# 전군 출정하라
# : 부정
# 감동 그자체
# : 긍정
# 백의종군 당하고 병약하고 힘빠진 이순신 역할에 최민식이 어울림 전성기 시절 이순신은 김명민이 딱이고
# : 긍정
# 이순진장군 외계인 장군 이나라 지키신 분 선조 는 미친놈 의심병 환자
# : 긍정
# 임진왜란 관련 영화나 드라마만 보면 드는 생각 원균 뷰웅신 새끼 원씨 가문은 연좌제가 마땅하다
# : 부정
# 너무 멋져요 눈물난다 진짜 존경합니다
# : 긍정
# 이런 연출을 보고 촌스럽다고 하는거임 전랑 보다 조금 나은수준
# : 긍정
# 아니 마지막에 국뽕에 차올라 보고 있는데 갑자기 이야 이래서 당황 했음
# : 부정
# 우리역사는 길이 길이 알려저 온세상이 빛나리라 수많은 분들과 그수하 장군들 그리고 이순신 장군께 다시 한번 진심으로 진심으로 우리를 지금 여기에 있게 해주셔서 감사 드리고 모든 분들게 또한번 감사 드립니다 부디 천국에선 전쟁없는 세상에서 행복하시길 간절히 바랍니다
# : 긍정
# 최민식 배우님 촬영 시 나이가 명량 당시 이순신 나이와 같았다고 함 그래서 최민식 배우님은 이순신 장군의 인간적 고뇌와 고독함이 어땠을까 그런 것들을 엄청 연구했고 그걸 고스란히 극에 녹여내기 위해 많이 노력했다고 함
# : 긍정
# 돈팍 등 애국자 엔터테인먼트 대표 이창국 간첩들 공개
# : 긍정
# 가슴이 웅장해 지내요 너무 슬퍼요
# : 긍정
# 전투고증을 생각하면 불쾌할정도지만 무시하고 보면 재미있는 전쟁영화인듯
# : 긍정
# 디 티타잔타타타나재메메 꺄아아아아아아아아아아악
# : 부정
# 실제로 저 도도 다카도라 도 왼판에 화살을 맞았다는 일본의 기록이 있으니 얼마나 대단한 승리인지
# : 긍정
# 개간지 속시원함 어떻게 화승총이 스나이퍼도 아니고 저거리에 닿냐 설정
# : 긍정
# 일본애들은 아직도 이순신하면 소설속 허구의 인물인줄 암 그만큼 소설속에서나 나올법한 대단한 실존 위인이긴한데 물론 절대 자기네가 처참하게 패배했다고 교육하진 않겠지 그래서 허구의 인물인줄 암
# : 부정
# 이순신장군의 미친전략
# : 부정
# 대성통곡함 국뽕
# : 부정
# 하지만 피파온라인 를 하던 유저들은 모두 일본에 동정을 느끼기 시작하는데
# : 부정
# 가장 결정적인 장면 초 일본 전군이 이순신배 하나를 총공격했는데 이순신이 죽을 각오로 싸워 살아남으니 우리의 뒤로 빠졌던 배들이 척이 배 하나를 못이기는데 우리가 가면 분명 이길 수 있다 고 생각하며 기세가 오르고 일본은 척이 배 하나를 못 이기는데 뒤에 있는 척이 합류하면 과연 이길 수 있을까 두려워하며 전세가 순식간에 바뀐 것 같군요 이것이 바로 이순신장군민이 두려움을 용기로 바꾸기 위해 내가 죽어야 할 것 아라고 하셨던 이유가 아닌가 합니다
# : 긍정
# 이순신장군님은 죽고자 하면 필히 살 것이요 살고자 하면 필히 죽을 것이다 라고 하셨는데 우린 우크라이나 사람들이 생사의 위기에 처해 도와달라고 하는데 러시아 무섭다며 우리만 살겠다고 도와줄 수 없다고 했다니 정말 부끄럽네요 과연 이것이 진정 사는 길인지 모르겠네요 오히려 지금 북중러 국 혈맹에 둘러싸인 상황에서 미국과 다른 우방들의 비판을 받으며 힘들게 미군이 한국을 지켜 줄 가치가 있냐는 회의론이 고개를 들며 더 큰 위기에 처하게 된 것 같더군요
# : 긍정
# 다들 국뽕 주의 하세요
# : 부정
# 이순신 장군에 대한 사실은 언제 봐도 감동이고 최민식 배우의 이순신이 지금까지 모든 이순신 장군 중 역대 최고라 생각 됩니다
# : 긍정
# 전세계해군명장 안에 들어가있으면 말다했지뭐
# : 부정
# 모두가 미쳤다고 했는데 그걸 이겨버렸는데 이거만 봐도 충무공이 사람인가 싶음
# : 긍정
# 별 감동이 없었던 최민식씨 연기
# : 부정
# 한국사회를 싫어하면서도 친일파는 도저히 못되겠다 바보같은 이순신 장군님
# : 부정
# 미국 유럽 지원받고도 겨우 싸우는 우크라이나 보면서 이순신 장군이 얼마나 대단한 영웅인지 깨닫습니다
# : 부정
# 참 이상한게 어치 한낯 해적이었던 사람을 전장에 세우는거 미친거아니야 그니까 개터지지 히데요시가 저때 노망 군하고해적이라 상대가 안되지
# : 긍정
# 을지문덕 세종대왕 이순신 이 세분은 소설도 이렇게 쓰면 욕먹음
# : 부정
# 명장이야 당연히 칭송 되겟지만 그 명장의 명령을 바로바로 진행시킬수 잇는 아래 장수들이 잇다는건 저배엔 그냥 전쟁의 명장들이 다 잇엇다는거지 이름은 안불리지만 또 다른 이순신이 저배에 잇엇다는것도
# : 긍정
# 이렇게 멋진 영화를 만드신 감독님과 배우님들께 존경을 표합니다 감독님 대한민국이 좋아 우리나라에 와서 열심히 연기하신 일본인 배우님들께서도 여러 작품에 출연하셨서 전세계적으로 인정받으시는 대배우님들이 되셨으면 좋겠습니다 그래서 함께 얼싸안고 웃었으면 좋겠습니다
# : 긍정
# 이거 보고 나는 왜 울고 있냐고 괜히 울컥하네
# : 긍정
# 현실은 고증 저세상으로 날려버린 영화
# : 긍정
# 성웅 충무공 이순신 장군 탄신일 월 일
# : 부정
# 진짜 언제봐도 가슴이 웅장해진다 최민식님 연기는 역시 믿고 본다 정말
# : 긍정
# 한산 개봉일 확정 월말 어떻게 기다리냐
# : 긍정
# 존경합니다
# : 긍정
# 이순신 화포를 배 아래 갑판으로 모조리 집중하려고 하네 되겠느냐 나대용 그러면 다 죽습니다 이순신 된다고 말하게 나대용 네 해보겠습니다 저는 이 장면이 이론적으로는 위험한걸 알지만 이순신 장군을 믿고 자기 생각은 뒤로한채 상관에 지휘를 따르는 모습도 굉장히 명장면 이라고 생각합니다 그래서 화포로 포위된 대의 일본선을 집중타격으로 격침시킨 이후 두려워하던 병사들의 사기가 도 바뀌어 용기를 내어 일본군을 쓰러트리는 시작점을 만들었던 중요한 장면이라 봅니다
# : 긍정
# 필생즉사 필사즉생
# : 부정
# 룽 넏 넡 노턶너뇨녀
# : 부정
# 일뽕들 뒤지게많네 건너가서 살아라 남의땅 오지말고
# : 부정
# 이순신 이름빨로 천만 찍은거 같다 선점 효과 때문인지 몰라도 김명민이 나한텐 그냥 이순신이고 참 보면 충무공은 위대하다
# : 부정
# 퀄리티 도 대박
# : 긍정
# 목 배기 무서위
# : 긍정
# 영화관을 거의 안가시던 할아버지가 이순신 장군님이 나온다해 당시 주위 어르신분들의 단체 상영도 유행이라 보러갔는데 후회만하심
# : 긍정
# 최민식 배우도 연기 잘하지만 이순신은 김명민이 넘사벽인듯
# : 긍정
# 국뽕 하는 놈들은 매국노보다 나쁜 놈들이다
# : 부정
# 년 아베는 우리가 북한 무기의 원료를 생산한다는 말도안돼는 이유로 우리 경제와 산업의 핵심 제품의 원료들의 수출을 중단했다 그때 모든 기레기들과 숨어있던 친일파들이 아베에 무릎을 꿇고 용서를 빌라고 했다 주옥순 어머니연합 대표는 광화문 소녀상 옆에서 아베에 엎드려 사죄하는 퍼포먼스까지 했었다 그때 문재인 대통령은 참모진들의 우려에도 지금이 기회다 지금이 소부장 소재부품장비 산업을 독립시키고 키워야 할때다 그렇지 않으면 영원히 일본의 가마우지 경제로 살아
# : 부정
# 그야말로 국뽕에 흥행은 성공했지만 이영화가 국뽕 마케팅 만 없었음 이렇게 흥행할까 싶은 역대급 거품 영화임 이거보고 불멸의 이순신 다시보가로 봤는데 부작이였나 그렇게 길어도 불멸의 이순신이 몰입도 잘되고 훨씬 재밌었음
# : 부정
# 그냥 이순신이네 이순신
# : 긍정
# 최민식 사극은진짜아님
# : 부정
# 우리나라는위대한민족이다빨갱이를때려잡자 멸공
# : 부정
# 역시 이순신은 김명민이다
# : 긍정
# 넷플에서 연재하면 좋겠군요
# : 긍정
# 그 옛날 칼의 노래를 읽고 실제 그러한가하고 울돌목에 갔을 때에 봤었죠 진짜로 저렇게 신기하게 돌고도는 신기한 물살이었어요 물론 늘 그렇지는 않은 곳이긴하나 역시 그 옛날에도 지금도 제 눈으로 보아도 물살이 기이하고 거친 곳이더라구요 그리고 참 저 곳에서는 수많은 고깃배들의 도움이 아니었더라면 결코 빠져나올 수가 없는건 사실인 것 혹시 궁금하시면 한 번 다녀오세요 정말 신기한 곳입니다
# : 긍정
# 노량아 기다린다
# : 긍정
# 왜 일본은 조선 수군에게 저준 것일까 꼴랑 척에 그냥 지들끼리 자중지란은 아닐까 지금의 민주당처럼 이재명이 먹나 문빠가 유지하나 뭐 이런 거
# : 부정
# 영화 이름이 뭔가요
# : 부정
# 난 명장면이 여자같이 생긴 암살자 눈을 화살로 맞춘 장면이 맘에 듬
# : 긍정
# 우리 덕수이가의 자랑스러운 조상님 후후
# : 긍정
# 일본에게 굽신거리는 부끄러운 윤석열과 국민의힘 일본이 윤석열 당선을 환영하더니 역시 굴욕적 친일왜교 시작되었다
# : 부정
# 레전드긴 하지
# : 긍정
# 난 뭐니뭐니해도 이순신은 김명민이 갑이라고 생각한다
# : 부정
# 대장선 척만나가서 싸운게 저것마저 상대의심리전을유도한 전략아닌가 문득 이런생각을해봅니다 군기와 이순신에대한믿음감이 강했을건데 오합지졸처럼보이게해놓코 일본군이 의심없이 울돌목까지 오게끔할려는 고도의 심리전
# : 부정
# 노량 언제나와
# : 긍정
# 이순신 멋져요
# : 긍정
# 그 쌓인 원한 일제 강점기 징용 정신대매춘 학살등 그 모든을 미국이 히로시마 나가사기 토쿄 대공습등으로 갚아줌
# : 부정
# 아 씨 이거 다음 영상 추천이 왜 악마를 보았다 인데
# : 긍정
# 시발 선조여 하 미것네 푸틴 이냐
# : 긍정
# 역시 극한의 상황에서도 절망하지 않고 끝까지 자신들을 버리려 했던 나라와 자신들을 믿는 백성들을 위해 처절하게 싸우시는 모습이 너무 감동적이네요 특히 백병전 전투에서는 우리 조상님들이 자신의 몸을 사리시지 않고 혈투를 버리는 모습에서 그분들이 있기에 지금의 우리가 존재한다는 사실이 뇌리에 박히네요
# : 긍정
# 걍 보면 온몸에 물 이란물 다나옴 홍수주의보 보 예노지
# : 부정
# 아 옛날에 보 예 노 지 때매 날밤깜 얘 요물임 진짜
# : 부정
# 우리나라 물부족국가라고 누가그랬냐 보 예노지 쳐보면 그런말 안나옴
# : 부정
# 긴급속보 보 예 노 지 실시간 방송도 킨다는데 여기다 좌표찍기좀 그렇다 아무대나 쳐도나옴
# : 부정
# 보예노 지 가 대체 뭔데 그냥 검색하면 나옴
# : 부정
# 보예노 지 영상 안본사람 없을껄 딱 녀 보다 유명한게 보예 노 지 인데
# : 부정
# 보 예 노지 는 믿고보는 영상 아니니 오늘 꿀잠각 개꿀
# : 긍정
# 이번에 보예노 지 영상 또 터진거임 어디서 볼수있냐
# : 긍정
# 난 벌써 저장 해놈 보예노 지 진짜 물건임 다른거보곤 반응도 없는데
# : 부정
# 여기다 말하기 좀 그런데 그냥 아무대나 보 예 노 지 쳐보셈 바로나옴
# : 부정
# 뭐냐 진짜 네이버에만 쳐봐도 나오네 보 예노지 이렇게 유명했음
# : 긍정
# 보 예 노 지 복귀한다니 여자들 긴장해야겠네
# : 부정
# 보예 노지 영상 떳다구 바로 사라지는거아니냐 또
# : 부정
# 얘 대한민국 남자들이면 모르는애 없을껄 보예 노 지 워낙 유명하잖어
# : 부정
# 그 내가아는 보 예 노지 맞음 네이버 실검 실화냐 이거
# : 긍정
# 진짜네 네이버에 보 예 노 지 쳐서 나올정도면
# : 부정
# 와 님들 그거암 보 예노지 복귀했음 네이버에 쳐도나옴
# : 긍정
# 바다판 테르모필레 전투
# : 긍정
# 보통 영화 보면서 이게 말이 되냐고 이렇게 나와야 정상인데 이건 실화 보면서 이게 말이 되냐고 이정도니 완전 사기캐릭터 이순신 장군
# : 부정
# 이순신 장군님뿐만아니라 모든분들이 이길수도 없는 전쟁을 이겨버리고 참으로대단하다
# : 긍정
# 진짜 저 상황에 아군함선들이 뒤로 후퇴를 했으면 일반적인 지휘관이었으면 전투고 뭐고 가서 목을 따버릴것이야 라며 흥분했을텐데 침착하네 역시 갓순신
# : 부정
# 내가 생각하는 최민식 배우님의 역대 영화 명량 이순신장군님 빙의 했다고 봐도 무방한 연기를 선 보이셨음
# : 긍정
# 전투신 이리 올려주면 안짤리나 너무좋다
# : 긍정
# 충무공
# : 부정
# 한명이 길목을 잘 지켜내면 천명의 적도 떨게 할 수 있다 하였다
# : 부정
# 내가 너 좋아하면 안되냐
# : 부정
# 노량해전을 감동적으로 만들어주세요
# : 긍정
# 해병대정신은 이순신장군님으로부터 나온거같다
# : 긍정
# 충무공의 혼이 우크라이나도 지켜주기를
# : 부정
# 년 월 일에 보는 명량 조상님들 감사 합니다
# : 긍정
# 일본배들 개작네 뽀로로 장난감이누
# : 부정
# 눈물이 차올라 와 대단 해
# : 긍정
# 가장 결정적인 장면 적들이 온 힘을 다해 총공격을 가했는데 죽지 않고 살아 나오는 것을 보고 적은 기겁을 하고 우리측은 힘을 얻어 뒤에 쳐져있던 함선들이 합류하면서 전세가 순식간에 바뀐 것 같군요 척이 한 척을 못당하는데 나머지 병선이 합류하면 어떻게 되겠는가를 생각하면 당연한 것이죠 이것이 이순신장군님이 자신이 죽어야 할 것이라고 말한 이유 자신이 죽기를 각오하고 싸우는 것을 보면 두려워하던 부하들이 용기를 얻고 적들은 그 기세에 눌려 전세가 순식간에
# : 긍정
# 배나온 아저씨 게으른 아저씨 전선 최전방에 나올 장수는 아닌것 같음 명성에 맞는 배우긴 하지만 미스 캐스팅
# : 부정
# 이순신 장군님 우리나라를 지켜주셔서 감사합니다
# : 긍정
# 놔둬라 제일 명언 나머지 개 후접 어스레기들
# : 부정
# 너무 영화같아 영화지만 최종병기 활 감독이 제작한다해서 걱정했는데 딱 들어맞은 작품 이 작품에 찬사를 보내는 것도 이순신을 향한 생각이고 오히려 인물을 더 깍아내린 영화
# : 긍정
# 난중일기 보면 초반에 대장선 척으로 상대한거라고 나와있습니다 초요기를 올린 시점부터 해서 거제현령 안위랑 다른장군 한명이 붙어서 영화에 나오는거 처럼 그 지점을 지켜내시죠 그리고 거의 전투가 막바지 쯤에 나머지 쫄보장수들이 붙지요
# : 긍정
# 단순한 국뽕 졸작 영화 진짜 흥행이 이해 안가는 영화 차라리 국뽕 영화면 그나마 암살이 낫고 비극적 이야기를 그린 남한산성에 비하면 작품성이 현저히 떨어지는 영화 그렇다고 재미가 있었다기에도 애매했던 영화 그냥 중 장년층의 애국심 하나로 흥행한 영화
# : 부정
# 울컥하네요 백년 이상 회자될 명작입니다
# : 긍정
# 충무공 이순신 존경합니다 뒤를 따르겠습니다 일본 중국 러시아 그 어디가 침공해와도
# : 부정
# 저는이영화 진심으로 영화관에서 번보며 같은장면서 눈물이 가슴속 깊은곳에서 부터 무언가 올라오는것이 대박인 영화이였습니다 우리나라 최초 세계최고의 명장 이순신장군님 영광입니다
# : 긍정
# 영상 정말 잘 만드시네요 영상 감사합니다 최고 조폭영화는 매우궁금하시죠 놀라실겁니다 한번와주세요 최민식 연기는 최고인듯요
# : 긍정
# 이순신 장군님은 세계사에서 찾을수 없는 위대한 영웅 이다
# : 긍정
# 저 안위라는 장군은 명량해전의 공을 나누어서 보고한 덕에 함대사령관으로 영전합니다
# : 부정
# 해치웠나
# : 부정
# 이거 보니까 불멸의 이순신 생각난다 거북선 판옥선 진짜 쎄다 일본이 져버렸어
# : 부정
# 울둘목은 운다 이순신의 구국의 울음을 안고 이시대에도 장구한 세월을 흘러 나라를 구한 난세의 영웅이야기를 오늘도 들려준다
# : 긍정
# 실재는 척인 이순신 장군이 타있는 배만 전쟁 초중때 싸우고 뒤에 있는 나머지 배들은 머뭇거리다가 후반때 이기는것 같아서 후반때 도와줬다네요
# : 긍정
# 전쟁은 힘으로만 하는것이 아니다 머리로 해야 하는것이다 힘과 머리가 합쳐지고 그에따라 실전같은 훈련만이 승리를 보장할수 있습니다 훈련중 흘린땀 한방울이 전시 피한방울이다
# : 긍정
# 최민식이가 한게 별로 없는영화
# : 부정
# 모오오오두두두 백병전을 준비하라라라라라
# : 긍정
# 이순신 목숨을 내걸고 이 나라를 지킨 진정한 애국자
# : 긍정
# 자막이 틀림 물살이 아니라 몰살
# : 부정
# 생사의문턱에서 조국과 민족의 안위를 위해 자살과 같은 공포를 이겨내고 싸워 우리민족을 지켜주신 모든 수군과 이순신 장군님께 감사드립니다
# : 긍정
# 나라가 힘들때 신라는 뒷통수 치고 백제 고구려는 나라를 지키고 지금도 경상도 아새끼들은 뒷통수 치고 쯧쯧쯧 먹을수 있어 좋구나
# : 긍정
# 정치에 희생댄 인 진짜 월 일 선거 잘합시다
# : 긍정
# 척인지 척인지 의미가 없다 일본어 공부를 한적 있어서 일본 사람의 특징중 메모를 한다 즉 기록이다 이순신의 기록은 일본에 더 많다 내가 확실히 아는건 이순신을 피해서 보급을 하려고 했고 일본군을 상륙시킨려고 한 사실이다 그리고 중앙박물관의 유물 몇배가 일본에있다
# : 부정
# 저기서 진구횽 역할이 뭐였죠
# : 긍정
# 불멸에 이순신도 소름이었은데 최민식 이순신도 소름이네요 국뽕 차오름니다
# : 긍정
# 내가 볼땐 영화 속에서 일본인이 줄을 던지는 것보다 조선 백성이 던지는 줄이 더 먼것 같다
# : 긍정
# 이순신 그는 신이다
# : 긍정
# 한국 명량 중국 전랑
# : 긍정
# 이순신장군님께서이겨주신덕분에지금의우리나라가있는것같고이순신장국님말고도유관순열사님등등저희나라를지켜주셔서감사합니다부디하늘에선행복하세요
# : 긍정
# 과거와 현재에 영웅이라면 이순신 장군입니다
# : 긍정
# 명량해전 임진왜란등 이런 전쟁들을보면 너무나도 멋있고 너무나도 소중하고 귀한사람들이 희생되었고 하지만 이 명량해전은 이순신장군이 있고 너무나도 멋있고 귀한사람들이 희생되었기에 이 명량해전이 더 이길수있었다고 생각합니다 이순신과 생일이 같은 월달이므로 너무나도 자랑스럽습니다 이 작품을위해 열연해주신 배우님들 너무나도 수고하셨습니다
# : 긍정
# 이 영상을 보며 이순신 장군님 얼마나 위대하신지 알게돼실겁니다
# : 긍정
# 네버다이를 능가하는 성웅 네버다이
# : 부정
# 불멸의 이순신이 더제밋는데 너실감이나고 이거강강술래도없잔아
# : 부정
# 장군 당신은 이나라의 영웅이십니다
# : 부정
# 그냥 영화 자채가 진짜 국뽕 터진드아
# : 부정
# 이순신 위임
# : 긍정
# 국뽕 제대로 몸속에 박힌 영화
# : 부정
# 신에게는 아직 열두척의 배가 있사옵나이다
# : 부정
# 진 자 린다
# : 긍정
# 오 고경표
# : 긍정
# 들아 선조들이 목숨 걸고 지킨 강산 앞으로도 잘 지키자
# : 긍정
# 와 나 이거 극장에서 볼때 미니건 한자루랑 총알 댓빵실고 내말 잘듣는 동생넘 델그가서 장군님 배에서 졸라 갈겨대고 싶더라 가치 가서 싸우고 싶더란거지 진심
# : 부정
# 성웅 이순신 장군님을 원 짜리에 참 어의가 없다 신사임당 보다 어찌 무시되는지정말 어의가 없다
# : 부정
# 오만원권에 신사임당이 아닌 이순신 장군님이 들어갔어야 옳다 아주 지멋대로지 박근혜때였나 명박이 때였나
# : 부정
# 회오리에서 구해주시는데 몸에소름이 정말존경하고 감사합니다 평생 은혜 잊지않으면서살겠습니다 이순신 장군님 외 모든 분들고생하셨고 다시한번감사합니다
# : 긍정
# 이순신 전하 신에게는 척의 항모전단이 있사옵니다
# : 긍정
# 이분이 있었기에 우리가 있고 우리가 있기에 미래가 있지
# : 긍정
# 요즘같이 군인들이 홀대받는 시대에 다음편이 개봉했으면하네요
# : 긍정
# 명랑해전 감독님 대단합니다 배우님들도 대단하시구요 명랑해전 부를 부탁합니다
# : 긍정
# 국뽕빼면 쓰레기영화
# : 부정
# 아무리 생각해도 이순신 장군님은 먼 미래에서 타임머신을 타고 조선으로 가서 한국 국민들을 살린 분이란 생각 밖에 안 들어요 당시 조선 시대 사람이 아닌 것 같음
# : 긍정
# 넷플에 왜 불멸의이순신 없냐 올라와랏
# : 부정
# 격군 분들이 하는말이 기억난다 후손들은 알까 우리가 얼마나 고생했는지 알아야지 그러면서 했던말
# : 긍정
# 이순신도 알까 자기 동상 있는거 본인이 세종대왕 급인거
# : 부정
# 아 조선 이순신 어쩔건데
# : 부정
# 꽃잎 에 나왔던 배우
# : 긍정
# 안위야
# : 부정
# 칼을 뽑으면 온 산과 강을 피로 물들인다
# : 긍정
# 맛있구나 허기지는데 잘됐구나 가 아니라 먹을 수 있어서 좋구나 맛을 얘기하는 것이 아니라 먹는 행위에 대한 기쁨 그것은 먹을 수 있는 행위에 대한 기대감을 내려놓고 출정했기 때문은 아닐지
# : 긍정
# 진짜 볼때마다 국뽕이 차오릅니다
# : 긍정
# 그 대사
# : 긍정
# 지금 대한민국 장군 장성 특 하는일없음
# : 긍정
# 미친 활의 민족
# : 긍정
# 재앙 정부에게도 마찬가지일듯 신 파시즘 거부합시다 죽고자 하면 살것이요
# : 부정
# 병신같은 조선에 하늘이 내린 장군과 하늘이 내린 백성들의 콜라보 조선 수군
# : 긍정
# 저 때나 지금이나 정치가 개판 인간이란
# : 부정
# 이순신장군이 제일 싫어했던게 백병전인데 최대한 피하려고했지 저렇게하지는 않았을거같네요
# : 부정
# 명중률 지림
# : 부정
# 놀라운것은 과장이 아니라 사실이라는것
# : 긍정
# 이순신 장군의 대장선은 백병전을 치루지 않았음 아마 안위의 판옥선이 도선하는 왜군을 맞아 백병전을 했지 대장선은 백병전이 없었음 화약선 공격도 당연히 왜곡임 전반적으로 불필요한 장면이나 왜곡된 장면이 너무 많아보임 역사적 사실을 기반으로 만든 영화라면 전반적으로 역사기록에 충실한 간결한 스토리텔링이 있었어야 됬음 간결하고 건조한 묘사 그렇지만 사실적인 전투씬이 가미 됬더라면 오히려 감동이 훨씬 더 했을 것 참으로 위대한 역사를 기반으로 만든 영화에 군더
# : 긍정
# 진짜 내가 조선 개싫어하는데 이건 존나 멋있다
# : 긍정
# 해군의 다짐 우리는 영예로운 충무공의 후예이다
# : 부정
# 이 모든 전투는 배설 장군덕임을 알아야합니다
# : 부정
# 이순신의 바다 이거 읽고 오신 분
# : 부정
# 토레타
# : 부정
# 새상에 다윗 징기스칸 티무르 나폴레옹 고레아 엘시드 원숭환 진시황 정 등등 수많은 명장과 정복자가 있지만 엇비슷한 군사력으로 전쟁을 치른다면 이순신을 능가할 장수는 아무도 없다고 확신합니다 혹시 제갈량이 일진일퇴를 할수 있을지 모르나 그외의 전사 를 보건데 이순신만한 충신이자 겸허한 인품의 명장은 세상에 없습니다
# : 긍정
# 윤석열은 이영화보고 빡치겄네 울고불고 난리일듯 토왜들 몰아내자
# : 부정
# 대로 발라버렷다는데 거북선이아니라 판옥선으로
# : 긍정
# 젓
# : 부정
# 쓸데없는 신파 난잡한 등장인물 고증 개박살 특히 전투 중간중간 자꾸 벙어리 여자랑 노인 마을 사람들 나오는 유치하고 어이없는 장면들 정말 전투씬 빼곤 다 형편없는 영화였음 이순신 장군님이라는 훌륭한 소재를 이따위로 날려먹다니 리메이크 되었으면 하는 영화 순위임
# : 부정
# 제 상상으로는 대장선 혼자 나가 싸우고 나머지는 뒤에 있었는데 어선들도 합세해서 멀리서 보면 병력이 많아보였을거라 합니다 작전이 아니었을까 합니다 병력이 많아 보여 왜군도 주춤했지만 대장선이 앞으로 나와있으니 그거 잡으러 달라들었을듯 대장선 잡으러 달려드는 배들이 대장선에 깨지면서 물살이 강해 지나친 배들은 뒤에 있던 배들이 깨버리구요 그렇게 야금야금 적들 깨버리다가 물살이 바뀌면서 뒤에 있던 배들도 같이 전진하며 원거리 공격 이때 왜군이 총 공격하고
# : 긍정
# 명량해전은 이순신 장군 혼자서 대장선을 지휘하면서 싸운게 맞다고 하네요 나머지는 겁먹고 뒤에서 구경만 했죠 을 승리로 이끈 셰계 최고의 위대한 명장 충무공 이순신
# : 긍정
# 나라를 구하기위해 희생하신 분들을 생각하면 눈물이 멈추지 않음
# : 긍정
# 엄청나게 많은 적과 내부로는 개 같이 험담하는 신하들과 질투많고 옹졸한 왕 그와중에 나라를 구한 이순신 장군
# : 긍정
# 이순신 장군님 하늘에서 편히 쉬십쇼
# : 긍정
# 벙어리 여자가 깃발 대신 옷을 흔드는 것과 일본군 저격수 연출만 아니면 완벽했던 영화
# : 부정
# 이정현 연기 진짜 소름 돋는다
# : 긍정
# 최민식은 명량을 안 맡아아 했어야햇다 최고의 졸작 이순신빨 로 흥행
# : 부정
# 민식아 넌 이순신은 영 아니다 명민좌께 연기지도 받고 와라 푸풋
# : 부정
# 조선에 이순신 장군이 안계셨다면 삼면이 바다인 조선 그때 끝 그러나 조선은 난새 성웅 이순신장군이 계셨습니다 다시 한번 후손인 우리가 감사드립니다
# : 긍정
# 높으신 분들에게 죽고못사는 노비들
# : 긍정
# 개명작인듯
# : 긍정
# 지금이야말로 죽기를각오하며 싸워야한다 그래야만 민주당이 아니 국민이살것이다
# : 긍정
# 문재인 민주당 정부 김치를 중국 파오차이로 해라 방탄소년단이 출연한 인터넷 라이브 방송에서 김치 의 중국어 자막을 파오차이 라고 표기해서 논란입니다 네이버 달려라 방탄 지난 일 파김치 잘 말아가지고 흰밥이랑 먹어야 되는데 중국이 김치 가 자기네 거라고 억지 주장할 때 쓰는 말인 파오차이 가 번역 자막으로 계속 나오는 이 영상에 대해서 네이버는 정부 훈령을 따랐다 고 했습니다
# : 부정
# 난 귀환하는 장군에게 절하는 백성의 모습에서 항상 닭살이 돋는다 진심이 느껴지는 진정한 지도자에 대한 존경심같은게 느껴지는
# : 긍정
# 고딩때 명량 영화관에서 보다가 수면하다 나온 기억이
# : 부정
# 차 진주성 전투의 김시민 장군과 차 진주성 전투에서 죽을것을 알면서도 성으로 자진해서 들어간 황진장군과 당시 대였으나 죽기를 각오하고 성을 지켰던 두 장군에 대해서도 영화만들어지면 좋을듯
# : 긍정
# 대한민국 만세
# : 긍정
# 최순신 그는 레전드입니다
# : 긍정
# 아니 대 을 해서 몇시간을 혼자 어떻게 버틴거냐
# : 부정
# 박근혜대통령이 임기때 이 영화들 본걸로 알고있는데 이영화들 보면서도 하늘에서 답을 준건데 어리석어 지금 이모양 이꼴이 된것임 국가가 형성될때 가장 근본이 국민인것을 몰랐던 것이이지 국민이 있어야 나라라있는것을 모르니 잘될수가 있겠냐구 지금도 모를거야
# : 긍정
# 이야 진짜 리더다 큰인물 역시 이순신장군님
# : 긍정
# 실제 이런 인물이 존재한건 나라의복이고 선조가있던건 개씹 이다
# : 긍정
# 이순신 장군님도 정말 대단하고 나라를 위해 같이 맞서 싸운 분들도 다들 존경합니다 조상들의
# : 긍정
# 장군 이시대에서는 저희는 어찌해야합니까 알려주세요
# : 긍정
# 우리는 영예로운 충무공의 후예이다
# : 부정
# 대명왕조 만력 년 조선왕조 대일전쟁 년부터 년까지 조선반도에서 일어난 전쟁 만력조선전쟁은 만력조선의 전쟁이라고도 하는데 만력원조조선전쟁 조선에서는 단장 임진조국전쟁이라고도 한다 한국은 다음과 같이 말한다 단장 임진왜란 일본에서는 문록이 단장 문록경장전역 이라 하는데 년부터 년까지 명조 만력 년에서 년까지 라고 한다 일본문록원년 경장 년 명조는 속국조선을 도와 일본의 침략에 항격하는 전쟁을 진행하였다 년 일본 태각 도요토미 히데요시 씨는 기본적으로 하루
# : 긍정
# 임진조국전쟁 임진왜란
# : 긍정
# 진짜 딱 지리는 장면들하고 대사까지 쫙 잘이어서 잘 모아놨다 팬티 좀
# : 긍정
# 항상 생각하는 것이지만 역사서에 꾸준히 기록되어오지 않았더라면 아무도 충무공의 업적을 믿지 않았을 것 같다 사실인 걸 알면서도 말이 되는 소리를 해야지 싶은데 그게 사실이고 역사라니 그저 놀라울 따름
# : 부정
# 이순신 장군은 바다의 신이라해도 되겠다 존경합니다 우리민족의 선조님
# : 부정
# 검은배는일본
# : 부정
# 비록 이씨는 아니지만 우리나라 성씨중에 가장 명문가는 덕수 이씨 가문이 아닌가 싶네요 대대로 나라를 위해 목숨을 아끼지않았고 독립군들도 많다고 하네요 이순신 이율곡 제가 덕수 이씨가문이면 자부심이 엄청날거같아요
# : 긍정
# 한국 여경들아 보고 배워라
# : 긍정
# 이 대그뽝이 우리 집안 사람이더라고 이랬던 분이 충무공 역을
# : 긍정
# 장군님 감사합니다
# : 긍정
# 보는 네네 가슴이 웅장해진다 이순신 장군님은 진짜로 전설이다
# : 긍정
# 감사합니다 우리나라를 주켜주셔서
# : 긍정
# 최민식 우리나라 진짜 국보
# : 긍정
# 대한독립만세
# : 긍정
# 국뽕 진짜 많이 차오를다
# : 부정
# 이순신안테총쏜사람누가밀어서자빠짐
# : 부정
# 근데조랑탄진짜위력강한거임
# : 긍정
# 척 척 웅장한전투
# : 부정
# 명량해전 각국 전력 조선 척 명 왜구 척 명 결과 조선군 부상자 명 전투로 인한 전사가 아닌 격군 포수의 이동 도중 외상 왜군 전사자 만 포로 명
# : 긍정
# 그에긍지높은 마지막은 우리에평범한삶을만들주었다
# : 부정
# 마군관 마군관 모두 위치로 적을 향해 돌격한다 적을 맞아 죽기로 싸울 것이다
# : 긍정
# 천운이엇다
# : 긍정
# 와 역시이순신 머쩌
# : 긍정
# 초 고슴도치
# : 부정
# 이순신장군님 인생이 어떤영화보다 더 극적이고 영화스러워서 제대로 담을수없다는게 너무 아쉽다
# : 긍정
# 조선시대 최고의 근접무기 호미
# : 부정
# 와 진짜 개 명대사
# : 긍정
# 저 당시 싸우는 사람들은 얼마나 두렵고 떨렸을까 진짜 멋있어
# : 긍정
# 이런 국뽕은 대찬성이지
# : 부정
# 똑똑한 사람들이면 눈치챈다 일본 배에는 대포가 없다는걸 총들고 싸우는 놈이 이기듯 대포들고 싸우면 이긴다
# : 부정
# 역시 일본은 배울것도 없고 나빠 그냥 없어지면 좋겠다
# : 부정
# 킈야
# : 부정
# 지금 이렇게 영상으로 각색한거만 봐도 경악스러운데 당시 일본쪽 대장들은 얼마나 끔찍했을까 죽었다 싶으면 살아있고 지는 싸움도 이기게 만드는 명장을 상대편으로 만나는 것 만큼 무서운건 없을 것 같네요
# : 긍정
# 이거 보면서 숙제하니까 잘됨 사회
# : 긍정
# 다시 봐도 명작인 영화
# : 긍정
# 감사합니다
# : 긍정
# 우리나라를 지켜주신 이순신님 항상 감사하고 그랜절 박겠습니다
# : 긍정
# 식민역사 조선시대만 다루지 말고 원삼국 시대 영화도 주제로 다뤄라 최근 출토된 백제 갑옷을 다뤄줘야 대중들이 알것 아닌가
# : 부정
# 누가 뭐래도 전세계역사상 장군중 가장 뛰어난 장군은 이순신장군이다
# : 긍정
# 장군님 저도 내년부터 장군님같은 훌륭한 해군이 되겠습니다
# : 긍정
# 이건 국뽕이 아니라 이순신은 세계역사 중에서도 탑급이 아니라 진짜 탑 오브 탑인 수군통제사임 척의 배로 척의 배를 막았다는게 전례 없는 전적이라서 과거에도 지금도 그리고 앞으로도 세계에 이순신 이상의 최고의 지장은 나타나지 않을 거임 무력 지력 통솔 다 합치면 세계적으로 항우 최고의 무장 알렉산드로스 최고의 정복왕 제갈량 최고의 군책사 이 셋이 탑급인데 이순신은 얘네에 필적하는 최고의 수군통제사임
# : 긍정
# 가슴이 웅장해진다
# : 긍정
# 전율 이순신장군님과 함께하신 우리 조상님들 감사합니다
# : 긍정
# 그 발언
# : 부정
# 이순신장군님이 나라를 위해 목숨바치는게 멋있고 존경스러우며 다좋은데 왜 조선은 성리학을 국시로 해서 나라를 망치고 도태 한건지 이해가 안됨 쓸데없는 성리학 쓸데없는 정도전의 재상정치체계 참 정신나간 발상같음
# : 긍정
# 어릴때 아버지랑 영화관가서 봤을땐 뭘 아는게 없어서 재미없었지만 지금 다시보니 정말 눈물난다 재개봉했음 좋겠다
# : 긍정
# 일본은 우리를 좀 놔주면 좋겠다 우리는 만주고토회복에 생각이있지 너네에게는 관심이없다
# : 부정
# 근데 어디 최씨 입니꺼 대구빡이 우리 집안사람 같은디
# : 긍정
# 이순신 장군님과 전쟁으로 죽은 영혼들을 추모합니다
# : 긍정
# 한산은 도대체 언제 출시될까
# : 긍정
# 우리나라 사람들 진짜 개똑똑한것 같음
# : 긍정
# 팩트는 저런 원거리 포격전도 뻥이고 백병전도 뻥이고 판옥선 척이 척 이상 상대 했다는 것도 뻥이고 마지막에 충격전술도 뻥이고 사실 명량해전에 대한 전술적인 기록이 없기 때문에 정확히 알 수 있는 것이 없는 것이 사실입니다
# : 긍정
# 네티즌 반응 가죽갑옷이 두정갑화된 조선수군 고증 고증 고증 대로 빼애액 찰갑이나 가죽갑옷입은 수군이었다면 그나마 이해 한다고 한다만 실제로 장수들은 두정갑에 찰갑이지만 명량에서 나온건 영화라 과장을 하거나 창작한 소품일 뿐임 그리고 창작이나 각색은 영화의 시나리오에서 기본이지 찰갑입은 이순신이 마음에 안들면 제발 의상제작 미술 의상팀 하고서 말하길 바란다 소품도 빡세게 하는 사극이다 주관적 생각 아니 조선 수군이 가죽 갑주를 입었어도 두정을 일반 병사가
# : 부정
# 이순신 장군님이 안계셨다면 아마 일본어를 쓰고있겠지 아니 못태어났을수도 감사합니다
# : 긍정
# 척으로 막았습니다
# : 부정
# 이순신의 승전고는 천재성과 용기 지도력 준비성 인문지식 의 산물이라고 생각합니다 재평가 될 부분이 많습니다 초상화도 외국에 최신 이미지 복구 기술을 이용해서 수정되었으면 좋겠습니다
# : 부정
# 황현필왈 외계인
# : 부정
# 탄탄하고 세심한 전략 결사항전의 정신 질수가없지
# : 긍정
# 아 장군
# : 긍정
# 이 되고 이기는 분위기 니까 이제야 오는
# : 긍정
# 에 판옥선 하나만 있는 걸 볼 수 있슴
# : 부정
# 이거는 사실상 판옥선 하나로 싸운 거임 나머지 배들은 거의 다 끝나고 이기는 분위기가 돼자 나옴 이거임
# : 부정
# 여기서 잠깐 정확히 척이 아닌 척 입니다 척은 이순신이 탄 배인데 그 외에 배들은 무서워 섬뒤로 숨었습니다 그리하여 대 개의 배중 척이나 없앴습니다 그리하여 힘이 빠지던 찰라 나머지 배가 나온겁니다
# : 긍정
# 이것도 너프해보시지
# : 부정
# 전쟁중에는 한국전쟁이 제일 인상적이고 한국전쟁에 나오신 분들이 제일 똑똑하신 분들이다
# : 부정
# 도고 헤이하치로 나를 넬슨제독에 비하는 것은 좋으나 이순신에 비하는 것은 감당하기 힘들다 이순신이 나의 함대를 가지고 있다면 세계를 제패했을 것이다
# : 긍정
# 굉장하십니다 짧은시간에 한편에 영화가 다들어있네요 진짜 진구연기할때랑 국민들이 배를 걸어서 꺼낼때 눈에 땀이 다 나네요
# : 긍정
# 장군님 존경하고 사랑합니다
# : 긍정
# 이순신 장군님 같은 사람이 또 나올까
# : 긍정
# 슬프면서도 영화관에서 제일 소름돋았던 장면
# : 긍정
# 싫어요 뭐임 일본인이냐
# : 부정
# 최민식 배우 좋아 하지만 이 역활은 다른 배우로 했으면
# : 부정
# 명량해전 다윗과 골리앗의 싸움에서 다윗이 이긴 실화
# : 긍정
# 이 영화가 역사왜곡인게 실제로 조선군은 피해가 저렇게 많지않았음 백병전도 있지도 않았고 왜군들은 오기도전에 대포맞고 침몰했음
# : 부정
# 아 눈물 나
# : 긍정
# 이건 마치 질럿 마리 저글링 마리와의 대결과 같을 것 같다
# : 부정
# 사람도 두려움이 있지
# : 부정
# 이순신 역보다는 개양아치 역이 어울려 혀가 잛아서 그런가
# : 부정
# 대한민국은 위대하다
# : 긍정
# 솔직히 백성들이 배타고 대장선 구하는것만 없었어도
# : 긍정
# 척이라는 학계의 정설
# : 부정
# 와키자카 병신아 해치웠나 부활주문 외울 때 부터 진거다
# : 긍정
# 최민식은 기본이 안되있네 살좀 쳐빼지 무슨 고초 다겪은 이순신이 저래 포동포동하냐 에휴
# : 부정
# 척 척 그것도 그냥 개처발랐지 영화는 너무 극적으로 연출했네
# : 부정
# 명량은 명랑해
# : 긍정
# 학교에서 명량 보고있는데 목잘리는거랑 눈에 화살 꼽하는거 보고 보통 여자에들은 다 눈 가림 나도 맞찬가짘
# : 부정
# 너무 멋졍 이건 국뽕 치사량이야
# : 부정
# 지리적 특성과 전략 모든것이 완벽했기에 가능한 전투
# : 긍정
# 여러분 지금 영화에서는 여러사람이 죽는 것 같지만 과거 역사에는 명 밖에 전사자가 없습니다 심지어 노 젓는 사람들까지 포함해서 명 하지만 현실이 너무 판타지라 영화에서는 저렇게 표현됬습니다
# : 부정
# 와 죽어야겠지 내가 하는 대사는 울컥하는 대사다 다시봐도 개소름돋네 최민식 어떻게 이런 인물이 꼴랑 원에 들어가 계시냐
# : 긍정
# 갑자기 이런생각이 나서 소름 돋았어요 일본과 또다시 전쟁할시 제 제 의 이순신 안중근 윤봉길이 나온다는 확신이 드니 소름이 돋네요 국뽕 충전 하고 갑니다 캬
# : 긍정
# 이 영화가 대박난건 이순신장군자체의 이름과 자세한 해전과정에 대한 기록이 거의 없는 해전에서 감독이 상상력을 잘 살려서 구현을 잘한게 몫이 큼 물론 고증이 완벽하지는 않지만 고증만 따져서 영화볼거면 영화보지말고 다큐멘터리 보러가는게 낫고
# : 긍정
# 아직까지 친일파틀 기득권을 차지하고 분열을 이르키는 이 현실 장군님이 보시면 얼마나 슬퍼하실까 자하당친일파들 이명 일본에서 태어남 박닭그네 부모가 친일장교 이승만 친일파 역사를 알아야한다
# : 부정
# 솔직히 영화 명량보다 불멸의 이순신 명량해전편이 더 재밌었음 현실적이고
# : 긍정
# 최민식 너 나보다 나이 많지만 죽는다 씨말노마 나도 우리 생낙지 먹으면 다 넌 조 가튼 새까더
# : 부정
# 이사람이 악마를 보았다 싸이코라고
# : 긍정
# 신에게는 겨우 척이 아닌 척의 배가 남아 있사 옵니다 한사람이 길목을 잘 지키면 천의 적군도 두렵게 할수 있다하니 척의 배는 결국 만 천 척의 배의 위력을 보일수가 있다는 결론
# : 긍정
# 이 전투가 이겨서 그렇지 우리나라에 부끄러운 역사임
# : 긍정
# 이순신님의 명언 나의 죽음을 적에게 알리지마라
# : 긍정
# 근데 한국은 항상 나라의 위기 때마다 저런 역사적 영웅들이 꼭 있어 왔다는게 더 신기함 그중 세종대왕님과 이순신이 특히 더 빛이 나시긴 하시지만
# : 긍정
# 이순신장군은 하늘이 내리신 명장이겠죠 그렇지 않고서는 저런 전과를 만들어낼수가없었겠죠
# : 긍정
# 이순신이겨라 이겨랏
# : 긍정
# 즈음 나오는 천자총통의 천지를 울리는 연출 지려버렸다
# : 부정
# 이순신장군넘
# : 긍정
# 여혐 영화군요 왜 여자는 없나요 멋진영화에 왜 남자뿐이 안나오죠
# : 부정
# 거북선으로 바뀌는 그장면이 간진대
# : 부정
# 활의 민족 총을 활로 대적하는 클라쓰
# : 부정
# 펑펑 울었답니다
# : 긍정
# 도대체 이해가 안되는전쟁 척으로 여척을 물리침 난중일기에는 왜 다른 장수들을 많이 비난햇는지 이해불가 한국의 존경받는 가장 위대한 장군님
# : 긍정
# 판옥선의 장점을 최대한 살렸겠죠 세키부네랑 판옥선 높이차이 감안하면 어떻게든 일본은 올라타야 도선 하는데 그거 막으면서 함포로 배 부셔가며 버텼을건데 나중에 안위 김응함이 합류해서 대가 울돌목 막은거임 정오 때 물길 바뀌면서 역류로 진도 밑으로 흘러나가니 물길도 조선수군의 편이 되어준거고 아무튼 이순신의 존버가 잘 먹혀들어간 전투임
# : 부정
# 수군들이 갑옷을 입었다는 영화속 코디는 사실이 아닙니다 사극 불멸의 이순신이 훨씬 더 사실에 가까움 아 또 한가지 영화속 수군중 분의 이 승병들이었다는 사실 사찰에 스님들이 승병으로 참전함 한국불교는 호국불교임 우리가 잘 아는 행주대첩도 권율 이름만 나오지만 실제론 행주성에서 싸운 조선군 분의 이 승병들이었음 임진왜란을 일으킨 히데요시 뒤엔 포르투갈 예수회가 있었음 이들이 조총을 히데요시에게 주는 바람에 일본 전국 통일이 일어났고 이어 예수회는 히데요시
# : 긍정
# 더이상 대체 할 함대가 없는 상황 이번 해전에서 한번지면 모든게 끝인 상황에서 이기는 싸움이 아니면 절대 해선 안될 절체절명의 해전이였죠 저때 이순신 장군의 심경이 어땠을까 척 정설 밖에 없는 상황에서 정말 어마어마한 압박을 받으셨을거 같네요
# : 긍정
# 진짜 명장면은 국민들이 놈들하면서 낫들고 달려갈땐데
# : 긍정
# 이거 구라던데 척이아니라 단 한척으로 버티고 싸운거임 나머지 병력들은 눈치보고 이겼다싶으니 나온거고 정말 감사합니다
# : 부정
# 타임머신이 있다면 저 전투를 실제로 보고싶다
# : 긍정
# 안위가 저 쪽국 저격수 잡고 이순신 대사 영화관에서는 저거 보고 이상하게 눈물이 날 정도로 지렸음
# : 긍정
# 척 개지리네
# : 부정
# 개인적으로는 아쉬운게 마지막 해전인 노량해전은 이순신은 참가를 안할수 있었죠 그건 일본군들이 후퇴하는 전투였습니다 고니시 유키나카는 이미 중국 총사령관 유정에게 뇌물을 줘서 밤중에 몰래 빠져나가도 좋다는 합의를 조선빼고 했고 밤중에 이순신은 무릎을 꿇고 유정에게 저들을 그냥 보낼수 없다고 사정을 해서 유정이 그 부탁을 들어주고 같이 싸우러 나갑니다 그리고 살아서 고향으로 돌아가겟다는 일본군과 절대로 그냥 보낼수 없다는 연합군과의 전투에서 이순신은 목숨을
# : 긍정
# 다좋은데 구루지마 투구가 에러였음
# : 부정
# 이순신 충무공은 국뽕으로 폄훼할 대상이 아니다 개돼지들이나 국뽕으로 폄훼하지 사람이라면 사람이라면 충무공을 숙연히 받아들이지 아니할 수 없다
# : 부정
# 이순신장군은 왜를 우리는 코로나를
# : 긍정
# 언제나 봐도 웅장하고 멋있는 영화다
# : 긍정
# 김윤석 배우님이 연기하는 이순신 장군 노량 죽음의 바다 기대중입니다
# : 부정
# 이 새벽에 진짜 가슴이 존나 웅장해진다
# : 긍정
# 이게 판타지 소설이 아닌 실제 우리나라 역사에 기반을 두었다는 사실에 오늘도 국뽕 한 사발 들이키고 갑니다 크으 국뽕 맛 지기고 이순신 장군님 감사합니다
# : 긍정
# 이순신같이 조정에 충성한 장군 덕분에 조선인의 를 차지하는 노예제도는 년 더 가게 되었죠 이순신이 일본으로부터 조선인들을 보호하려고 출정을 한것은 아닙니다 단지 조정에 충성 했을뿐이죠 오히려 한일합방 이후로 노예제도가 사라졌습니다
# : 긍정
# 먹을수 이써 좋구나 저도요
# : 긍정
# 된다고 말하라 흑흑
# : 부정
# 진짜 전투 결정만으로도 대단한데 승리로 이끌어서 경이로움 어떻게 이긴거지
# : 긍정
# 장군님 존경합니다 하늘에서 보고계시나요 감사합니다
# : 긍정
# 명량 핫도그
# : 긍정
# 난 어렸을때 기공신포로 왜군들 다 죽인줄 알았는데
# : 긍정
# 명랑핫도그
# : 부정
# 다른 국민의눈을 가리는 이상한 국뽕 유튜버보다 이 영화 한편에 국뽕이 차오른다
# : 긍정
# 이 영화를 보고 제 가 웅장해지다 못해 비틀려버렸습니다
# : 부정
# 모르는 사라이보면 그냥 자살 특공대
# : 부정
# 츼그미니
# : 긍정
# 호로자식들 안될려고 역사 절대 안잊겠습니다
# : 부정
# 저거는 이순신 비하나 마찬가지지 그냥 별다른 대책 없이 싸우러 간건데 운좋게 백성들 도움으로 이겼다는 거나 마찬가진데 더군다나 휘하 병력들을 제대로 장악하지도 못했다는 말이고 실제 이순신은 저런게 아니라 병력이 후달리는데도 그냥 여유있게 이겼고 전술적으로 압승한건데 이건 역사 왜곡 겸 이순신 비하임
# : 부정
# 최민식님은 배우 연기인생 최대의 고난 이었다고 스스로 밝혔죠 얼마나 막중했을까요
# : 부정
# 스님들은 풀만 먹고 어떻게 잘 싸우시는거지
# : 부정
# 장군님 얼굴에서 자꾸 악마를 보았다가 떠올라서
# : 긍정
# 개봉첫날에 공부하다말고 보러갔지
# : 긍정
# 최민식도 힘들었을꺼야 이순신이라니 근데 그느낌을 최대한 자기생각대로 한거같아 눈빛이없는 그저 모아니면 도 그리고 말하는것도 죽는거 아니면 사는거 그걸 근데 이순신을 알았을꺼야 확실하다는걸 왜냐면 아무 느낌도 없이 전쟁에 임하면 그렇게 대장선 혼자로 싸울수 없거든 난 이순신이 실제에있다면 살기를 띄고있고 국민들에게는 최대한 자제해서 이야기했을거라고 봐
# : 긍정
# 성웅 이순신 우리나라에서 최고의 충신이자 최고로 위대한 분
# : 긍정
# 자랑스러운게 아니구 저 영령이 있어서 우리 가 잇는 것이요
# : 부정
# 가장 결정적인 장면 적들이 온 힘을 다해 총공격을 가했는데 죽지 않고 살아 나오는 것을 보고 적은 기겁을 하고 우리측은 힘을 얻어 뒤에 쳐져있던 함선들이 합류하면서 전세가 순식간에 바뀐 것 같군요 척이 한 척을 못당하는데 나머지 병선이 함류하면 어떻게 되겠는가를 생각하면 당연한 것이죠 이것이 이순신장군님이 자신이 죽어야 할 것이라고 말한 이유 자신이 죽기를 각오하고 싸우는 것을 보면 두려워하던 부하들이 용기를 얻고 적들은 그 기세에 눌려 전세가 순식간에
# : 긍정
# 진짜 이순신은 조선을 살리려고 하늘이 보낸 인물 바다에서 오는 적은 바다에서 막아내야합니다 적이 상륙하는 순간 백성들은 비참해짐
# : 부정
# 난 솔직히 우리나라 역사상 가장 위대한 인물이 아닌가 생각든다 두번째로는 세종대왕님
# : 긍정
# 이순신 선조에게는 신하일 뿐이었는지 모르나 그 후손들인 우리에겐 신이다 그러니까 배의 두려움은 적선 하나를 격파하면 로 줄어들고 또 한 척을 격파하면 로 줄어들어가며 줄어드는 그 크기만큼 용기로 채워지는 거다
# : 부정
# 이장면 개멋있네
# : 긍정
# 너무 존경했기에 젊은시절 군대도 해군지원해서 복무했었던 기억이 나네 좋은작품이었습니다
# : 긍정
# 솔직히 척은 과장인듯
# : 부정
# 개인적으로 이 장면이 제일 소름돋고 감동의 눈물과 가슴속에서 복받쳐 올라오는 전율이 나를 감쌌다 그냥 졸라 멋있음 불멸의 이순신
# : 긍정
# 이순신 장군 최고
# : 긍정
# 많은 전쟁역사가들이 이순신장군님을 평가하길 전쟁의 신이 인간 세계에 잠시 놀다간것이다
# : 긍정
# 더 잘하지 나 한국이 여자 이버 대나
# : 긍정
# 더주 잉 억 전족은 억넘는대 흠 그냥한구겡서 살고싶어서 흠 이건좀 흠
# : 부정
# 도 햐바라 인순이 아니다 이순신 잘해 니놈들 도얼마 못나가 외국 절태로 이놈들은 넘 세 휴 무기만드놈들이라더 줘 존 잘놀게
# : 긍정
# 움직이는모들 항공 선박 다 솨버려 도안대네 발 나앗다 가불지 라 어이 한국인이 외 무서운지 제대로
# : 부정
# 어이 제대로 흠
# : 부정
# 제대로 솨 삽세야
# : 부정
# 나도 지킨다 한국 흠 멋진놈들 한국남자들 잉덤벼일본이 갑자기 한국인드이 뭉친다 다 죽여버려 보이는거 솨
# : 긍정
# 한국 맞서 싸워라 일본 장비빨이다 우리가 이긴다 돌격 미국 샷건
# : 부정
# 이순신 장군님 뿐만 아니라 그에 맞서서 용감하게 그 뜻을 따라준 백성분들도 존경하고 기억해야함
# : 긍정
# 영화에서처럼 대장선 혼자 싸웠다던데 나머지 배들 구경하다가 이길것 같으니까 합류했다고 하던데
# : 부정
# 이 영화 기대하고 봤는데 역사왜곡 쩔어서 개 실망 함 상업영화의 한계를 보여줌 왜군은 저런식으로 도선한게 아니라 공성하듯이 아래에서 위로 올라갔음
# : 부정
# 이순신장군은 대단하지만 왜 천만이넘었는지는 의문인 개씹노잼영화 억지신파가가득함
# : 부정
# 아 진짜 너무 감사합니다 장군님 나라를 끝까지 지켜주셧네요
# : 긍정
# 먹을수있어서 좋구나 라는말이 너무 가슴이 벅차올라요
# : 긍정
# 한국 이기자아 일본 우리는 총인데 니네는 활로싸우냐 한국 척이 우리한테 지냐
# : 부정
# 척
# : 부정
# 유덕화도 이 영화를 보고 피가 끓는다고 했더군요 우리 중국은 왜 이런 영화를 못 만드나 한탄했다지요
# : 부정
# 패배했다면 지금 한반도는 일본이겠지
# : 부정
# 미친 나라와 미친 국민의 콜라보
# : 긍정
# 명작이다 영화관에서 못본게 아쉽네
# : 긍정
# 가슴이 뭉클해진다
# : 긍정
# 이런나라를 말아먹어
# : 부정
# 이순신 장군도 훌륭하지만 이정현이 진짜 훌륭한거 같다 나라를 위해서 남편을 죽이라고 하는 마음이 어떨까
# : 긍정
# 신에겐 아직 척의 배가 있사옵니다
# : 긍정
# 솔직히 스님이 언월도 들고 나오는게 너무 멋있었음
# : 긍정
# 살고자 하면 필히 죽을 것이요 또한 죽고자 하면 살 것이니
# : 긍정
# 임진왜란은 조선과 일본과의 전쟁이 아니라 로마 카톨릭 예수회의 조선침략입니다 임진왜란 때 만명의 조선인을 학살했지만 기독교 포교에 실패합니다 구한말 조선이 천주교를 탄압하자 미국은 가쓰라테프트 조약으로 조선을 일본의 식민지로 만들고 일본은 미국의 선교를 돕고 조선기독교는 일본의 식민지배를 돕습니다 이런 역사도 모르고 기독교를 믿는 한국인들이 많습니다 역사를 잊은 민족에게 미래는 없다
# : 긍정
# 배 단 척으로 척을 맞선 이순신장군님
# : 긍정
# 장군님 감사합니다 볼때마다 국뽕이차오른다
# : 긍정
# 우리도 쫄지말고 출정하자 도와주는 후군같은 것 앖다 필사즉생
# : 긍정
# 리버에 인스네어 뿌리고 시즈탱크로 박살
# : 긍정
# 아 시원한 포격
# : 부정
# 우리나라 양궁이 탑클래스인 이유
# : 부정
# 역사를 알면 이순신장군이 대단하기도 하지만 불쌍하기도 한게 대장선 혼자 왜군과 싸우는데 나머지는 눈치만보고 있었다는
# : 긍정
# 아무리 판옥선이 구조가 좋네 저들이 배가 약하네 해도 로 붙을 생각을 한다는것 자체가 나중에 결과 보니까 우리배가 더 튼튼하네 어쩌네지 실제로 적의 병력은 했을때 보고가 척입니다 하면 전의 상실인데 대단하다 진짜 최민식 연기짱
# : 긍정
# 이걸보고 내가슴이 웅장해졌다
# : 긍정
# 명량해전에서 일본군 격파한건 척이 아니라 사실 장군선 척으로 막은거임 나머지 척은 지휘관들이 쫄아서 전투 참여도 안하고 뒤에 숨어 있었음 오후쯤 넘어서야 한 지휘관이 겨우 참여한다음 끝에 돼서야 척이 된거임
# : 부정
# 명량은 지금봐도 너무 명작이다
# : 긍정
# 이렇게 지켜온 나라인데 다망처놨네
# : 부정
# 타치
# : 긍정
# 짝짝짝 집구석에서 전쟁하던 군대랑 대륙이랑 맞짱뜨던나라랑 상대 안됨 섬나라 전국시대 웃김
# : 부정
# 개인의 능력은 중요하지않다 리더의 능력이 어느정도이며 그러한 리더를 얼마나 신뢰하며 따르냐가 중요하다
# : 긍정
# 저때의 스님들은 불살을 하며 채식을 하지만 나라를 지킬때만 살인이 허용됬다고 하죠
# : 부정
# 적 조총수 눈알에 한발 넣는게 이상하지가 않다 카메라 뿌셔버리는 민족인데 암요
# : 부정
# 우리 역사엔 아픔과 억눌린 슬픔이 함께한다 일본이 우리를 다시슨 업신여기지 못하게 하리라
# : 긍정
# 지금 해군들이 이순신장군정신으로 훈련에임한다지
# : 긍정
# 한국판
# : 긍정
# 국뽕은 그리 달갑진 않은데 멋있어서 봐준다
# : 긍정
# 영화관에서만 번정도봣는데 봐도봐도 안질림
# : 긍정
# 명량대첩의 주 무대가 판옥선이라는 말이 사실이군요 화포를 쏘는데 배가 버티고 나중에는 돌격해서 배랑 서로 맞부딪히는데 안 부서지고 그대로 버티는거 보면 판옥선을 만든게 얼마나 다행인지 느껴지네요
# : 긍정
# 국뽕한사발 주시오
# : 부정
# 최민식이 다이어트만 극도로 했으면 훨씬 현실적이었을듯
# : 긍정
# 장군님이 마지막에 드신건 혹시 마늘인가요
# : 부정
# 죽고자 하는 생각으로 들어갔으니 척으로도 살수 있었던 것이다 프사
# : 긍정
# 이순신 장군이 아무리 태어난 사주팔자가 안좋아도 오랜 시간 지난 현제에서도 원짜리 엣날이나 지금이나 잔머리 잘 굴리는 법조계 사람들에 비해 처참
# : 긍정
# 분봤는데 왜 눈물이 나올라고하는거지
# : 긍정
# 고증이 잘된게 척으로 싸운게 아니라 척으로 척이랑 싸우다가 이길거 같으니까 나머지 배들이 합류 했다네요 더욱더 대단한 이순신 장군님입니다
# : 긍정
# 저런 충신들을 항상 뒤에서 모함하고 죽게만드는 쓰레기 정치인들이 항상문제야
# : 부정
# 김한민 감독은 역사극에 참 특화된 감독 이순신 장군에 대해 넣지도 빼지도 않은 듯한 연출을 보면 역사를 재미로만 볼순 없고 그래서도 안되지만 상당히 재미있게 봤고 마지막 부분 너무 가슴이 뭉클했다 최종병기 활을 봤을때도 그러했고 역사를 바탕으로한 영화는 아니였지만 핸드폰 이라는 영화도 너무 재미있게 봤음
# : 긍정
# 칼의노래 넣고 영상만들면 레전드각
# : 부정
# 지금은 경제전쟁 전시상황 이며 대한민국 모든 가용자산 총동원하여 반격해야 합니다 저 또한 참전 할것이며 악귀가 될것 입니다 대한조선 만세
# : 긍정
# 핫도그
# : 부정
# 척이 아닌 사실상 척 나머지 배는 쫄아서 초전에 돌진하지도 않음 이순신은 불멸의 존재다
# : 부정
# 이 사람 혹시 보이스 방제수 인가요
# : 부정
# 일본새끼들은 이순신장군 전투를 우리가 지어낸 소설이라고 씨부리던데 정작 내세울 역사도 위인도 없어서 소설 오지게 쓰는 건 지들이면서 개뻔뻔함
# : 부정
# 에 왜 출장이라고 하는지 아시는 문과분
# : 긍정
# 한반도에 평화가 깃들자면 미국이 남한에 전개한 침략 무력과 전쟁 장비들부터 철거해야 한다 한미군사훈련을 중단하고 주한민군은 당장 철수하라
# : 부정
# 일본이 과거에 애써 신풍이나 뭐니 신의 나라로 자위했었지만 임진왜란 때 우리는 신이 이순신 장군님을 보내셨지
# : 부정
# 명량해전 승리 이후에 특히 이순신의 대장선을 탄 조선수군 병사들은 어떤 기분이었을지 그게 궁금 하네요
# : 긍정
# 화포 발사할때 전율이 크
# : 부정
# 국뽕이 치사량이네 먼저 감
# : 부정
# 아프칸 사람들에게 보여주고 싶다 평화는 거져오는것이 아니다 나라를 지키고자 했던 열정이 없으면 세계 최강 미국이 도와준들 삶의 터전을 지킬수 없다
# : 긍정
# 스님 멋있다
# : 긍정
# 어찌 나라를 빼앗는 자 가 나라를 잃고있는자의 간절함을 이길수 있으랴
# : 긍정
# 저때의 치열했던 상황을 생각하면 목숨걸고 싸운 조상들이 너무나도 감사하고 눈물이 계속난다
# : 긍정
# 신사임당 왜 만원에 들어가있나요 만원에는 이순신이 들어가야 한다 생각합니다
# : 부정
# 국민의짐 보고 있나 대한민국의 힘을 일본 니들이 돈 으로 대한민국 못이긴다
# : 긍정
# 솔직히 이순신은 전설속의 인물같음 교차검증을 통해 분석해봐도 기록은 분명히 돼있는데 존나 말이 그냥 안됨
# : 부정
# 진중권이가 그 때 뭐랬드라 뭐 작품성보다 최민식이 때문에 흥행했다고 이제보니 진석사가 친일파였더군
# : 부정
# 최익현씨는 내가 잘아는데 그사라믄 공무원이야
# : 부정
# 마 느그 칸파쿠 남천동 살제 내가 느그 칸파쿠랑 사우나도 같이 하고 밥도 같이 묵고 다 했어 임마
# : 부정
# 존나 왜곡 그 자체인 영화 는 실제로는 조선군 전사자 명뿐인데 영화에서 너무 많이 죽임
# : 부정
# 장군님 저희가 끌겠습니다에서 감동이였다
# : 긍정
# 일본도 인정하는 이순신 허나 인정하지않는 친일파 개들
# : 부정
# 장군은 신장이심니다
# : 부정
# 뭐가 되었던 버텼고 물리쳤다라는게 요즘 함포처럼 속사가 되는 것도 아니고
# : 긍정
# 그브 궁
# : 부정
# 정보 척으로 싸웠다는 건 거짓이다 대장선 혼자 오전 내내 버티고 싸웠다
# : 부정
# 상식적으로 척이랑 척은 이게 진짜 생각도 못 할텐데 정말 대단하다고 느껴진다
# : 긍정
# 상대방 입장에서는 진짜 욕나오겠다 자기네는 수송선단 포함 척 전투함만 보면 척을 몰고 왔는데 존나웃기잖아 분명 정보로는 척이 전부고 매복같은게 있을리가 없고 와 드디어 결판이 나나 싶은 기대감에 여기까지 온 나 정말 대단해 하면서 자존감풀충전이었을텐데 결과는 교환비 척 척 명 명
# : 부정
# 이런 지도자가 없는게 한탄스러울 뿐
# : 긍정
# 최민식이라서 좋았지만 최민식이라서 별로였다
# : 부정
# 저렇게 전쟁이 무섭게 나는데 어떡해 저런 데에다가 이순신은 몸을 바쳤지 저렇게 젊은 나이에 전쟁하다 죽은게 슬프다 이순신과 다른 유관순 전쟁에 몸을 바친 사람들에게 감사합시다 전쟁에 몸을 바친 사람들이 저희가 이렇게 잘살수있게 만들어준것 입니다
# : 긍정
# 지금에서야 이순신장군이 전설적인 인물로 모두의 존경을 받지만 그때 이순신장군 밑에서 싸우던 분들은 얼마나 미친놈으로 보였을까
# : 긍정
# 혹시 이정현이 왜 치마 흔드는지 아시는분 있나요 궁금해서요 진구배우분 나오는부분도 이해가 안되네요
# : 긍정
# 실제로 일본군은 쓰시마해역에서 러시아함대를 격파할떄 이순신의 전법을연구해서 사용해서 대파 했습니다 심지어 도고헤이치로제독은 이순신 장군을 존경한나머지 러시아 함대와의 전쟁전에 이순신장군에게 승리의 제사까지 지냈지요 고대부터 우리민족이 무너진대에는 항상 엘리트계층의 부패가 가장컸습니다 민중들은 늘 피흘려가며 이땅을 지켜왔죠 대한민국은 고대부터힘없는 백성들이 지킨나라입니다
# : 긍정
# 지금도 일본이 도발해서 전쟁이 난다면 마흔이 넘은 나도 자원입대할것이다 받아만 준다면
# : 긍정
# 척으로 혼자 싸우다 척이 도우러온거임 실제고증 제대로 표현함
# : 긍정
# 만일 그 두려움을 용기로 바꿀수만 있다면
# : 부정
# 감동이 밀려 오네 위대한 조국 대한민국
# : 긍정
# 뜨거워짐다
# : 긍정
# 저 전능하신 장군을 묻어버린 신라새끼들 경상도 새끼들이 문제인임
# : 부정
# 초 스님
# : 부정
# 명량 는 안나오나요 영화관에서 정말 재미있게 시청했는데
# : 긍정
# 코에이 삼국지에서 조운 조조 제갈량 먼치킨 수치의 능력치 인데 이순신 장군은 능력치로 과연 평가할수있을까 너무나 위대한 해군 제독 이순신
# : 긍정
# 내 인생 최고의 영화
# : 긍정
# 나발부는 왜군병사 저당시에도 아크릴안면 가면이생산될줄이야
# : 부정
# 민족 투사 오화영 님을 기리며 잘 봣습니다
# : 긍정
# 크으아이어아아
# : 긍정
# 그래서 올림픽때 이순신 장군 문구 현수막만 보고도 일본우익 애들이 그렇게 떨었나봅니다
# : 부정
# 정작 이장면 연출하고 젝작한 회사는 파산함
# : 부정
# 일본놈들에게 절대지지않는다
# : 긍정
# 명량해전은 올돌목에서 이루어진 전투가 아님 영화 판타지에서도 고증을 할 수 없다면 이건 실제로 가능하지 않다는 이야기 명량해전 그 어떠한 기록에서도 올돌목에서 이루어진 전투라고 적혀져 있지 않음 명량이라고 적혀져 있지 명량해협 안에 어딘가에서 이루어진 전투
# : 긍정
# 충무공 이순신은 민족의 영웅이 아니라 성웅입니다 성웅 이순신의 불굴의 정신을 이어받아 나라를 지키는데 힘을 모아야 할 것입니다 앞으로 성웅 이순신 장군의 한산 노량 대첩 영화가 상영되면 잘 보겠습니다
# : 긍정
# 이순신을 보는데 왜 남천동이 생각나냐
# : 긍정
# 정보 구루시마는 해적 출신 잡장이며 와키자카는 일본에서 듣보잡이다 오히려 비중이 적은 도도 다카토라가 훨씬 유명하다 일본에서도 이순신 장군은 유명하다 임진왜란때 활약한 조선수군의 용장으로 우리나라보다 용맹함에 초점을 더 준 이미지로 그려짐
# : 부정
# 광복절이라 보러 왔습니다 이순신 장군님 너무 감사드립니다
# : 긍정
# 와 영화로 보는데도 감당안될거같고 심장 졸여지는데 그당시엔 얼마나 더 무서웠을지
# : 긍정
# 국뽕이고 신파고 눈물이 안나올래야 안나올 수가 없다
# : 부정
# 최민식 버젼의 이순신도 좋았지만 머릿속에 박혀서 그런지 드라마 시절보다 년이나 흘렀으니 연기력이 보다 성숙해진 김명민 버젼의 이순신이었으면 어땠을까 싶다
# : 긍정
# 이 원혼들 어찌하리요 그만큼 잘못된 전쟁으로 인해 민초가 격어야 했던 힘든 세월을 바로 공감하는 전세계의 전설로 남을 수 밖에 없는 장군이시기에 이 존경의 마음을 말로도 다하지 못함을
# : 긍정
# 시대불문하고 이놈의 민족은 나라가해준거는 도없는데 위기때마다 영웅이 나와 이정도면 종특이란게 학계의 정설
# : 부정
# 내일이 광복절이라고 이영상 추천하는 알고리즘 칭찬해
# : 긍정
# 무의미한 팩트체크 난중일기 원본엔 일본수군은 척이다 유득공이 후대에 다시쓰면서 척으로 부풀렸음 명량해전 주일전 수리를 마친 척이 합류해서 척이 아닌 척이다 다시한번말하지만 척이든 척이든 무의미하다 팩트가 그렇다라는거다 명량해전은 위대한전투이고 이순신은 최고의 명장임에는 변함이없다
# : 긍정
# 이런걸 보면 당연히 감사하고 국뽕이 차오르는데 요새 머만 하면 국뽕 드립 쳐서 우리나라가 만족스러워야 말이지
# : 긍정
# 한국인이 어떻게 지금껏 이 나라를 지켜왔는지 단 적으로 보여준 영화 항상 열세에 있어도 끝까지 놓지 않았던 삶의 의지 또 뜨겁게 만든다 감사합니다
# : 긍정
# 진짜 우리 만족의 신이 강림하신거지
# : 긍정
# 이동국이 활약하는 영상
# : 긍정
# 와 류승룡 일어 발음 엄청 좋네
# : 긍정
# 살고자하면 죽는다
# : 부정
# 조선역사는 그냥 세종대왕 이순신 광해군만 가르치면 된다 끝
# : 부정
# 되겠느냐 그러다 다 죽습니다 된다고 말하게 예 해보겠습니다
# : 부정
# 솔직히 영화로만 보면 도대체 어떻게 천만관객이 본 영화인지 으
# : 부정
# 일본 방사능 올림픽으로 우리 이순신 장군이 세계에 각인됐다 일본놈들이 날뛰어 세계에 홍보한 효과 넘 가슴이 벅차다
# : 긍정
# 수군 복장이 왜저럼
# : 부정
# 국뽕이 아니고 역사다 늘 감사하게살고 역사를 잊지말자
# : 긍정
# 감사합니다 이순신장군 국민들
# : 긍정
# 우리나라가 양궁을 흽쓴게 인정이 된다
# : 부정
# 우리 양궁 금메달의 먼조상님 안위
# : 부정
# 조선의 판옥선은 항공모함 이다
# : 부정
# 해군 레전드 이순신장군님
# : 긍정
# 마 내가 일본군 장수 목도 베고 도망친 아군 목도 베고 마 다 했어 임마
# : 부정
# 고증 오류의 영화
# : 부정
# 해군에 다짐 우리는 영예로은 충무공에 후예이다
# : 부정
# 도요토미 히데요시가 죽을때 이순신 하면서 죽었다고 한다죠
# : 긍정
# 만세
# : 긍정
# 그 역사적 전투의 진실은 묻혔지만 생각해보면 영화보다 더 말도 안되는 일들이 일어나야 이기는 싸움 아닐까
# : 긍정
# 무서워
# : 부정
# 저 당시 헬조선아래서 고통받던 많은 백성들이 일본군에 붙어서 선조놈을 죽이려 했지 훗날 히로히토천황폐하께서 이씨조선강점기를 끝내고 일제해방기를 만들어 많은 불쌍한 조선인들을 구해주셨다 대일본제국 만세
# : 긍정
# 다시 봐도 전율이 돋네 정말 이순신이 대단한게 이미 미래를 예언한거임 앞으로의 전투는 사격이 아니라 함대함인 화포전쟁 즉 구축함 전쟁이 될거라고
# : 긍정
# 애국마케팅
# : 긍정
# 척인데 척이라하는애들 그냥 역사 공부안한거임
# : 부정
# 존나 멋있다
# : 긍정
# 진짜 국뽕 지린다
# : 부정
# 싫어요는 전부 일본놈들이겠구나
# : 부정
# 필사즉생 필생즉사 볼때마다 소름 돋음
# : 긍정
# 정확히말하자면 이맞지 구루지마부대랑싸운거지 도도랑 야쓰히루는 이순신의패왕색패기때문에 전쟁시작전기절한상태니까
# : 부정
# 임진왜란은 거의 일방적으로 줘털린 전쟁인데 영화는 졸라 전쟁 이긴것처럼 만들었음 이런거보면 우리나라도 국뽕 전교조식 역사관 역사왜곡 일본 중국 저리가라임
# : 부정
# 노비의 나라
# : 긍정
# 신에겐 척의 미항모가 있습니다
# : 긍정
# 이 아니라 이었음 영화가 사실 과장되게 왜곡한 면이 없지 않아 있지만 실제 기록을 봐도 좁은 해협에 대장선인 안택선이 동시에 진입하기 어려우니 작은 세키부네로 덤볐지만 우리 주력선인 판옥선이 세키부네보다 규모면에서 컸기에 판옥선을 못 이긴 것이고 이순신의 대장선만이 홀로 앞에 나와 버티고 버티다 조류의 흐름이 바뀌고 물살을 이용해 숫적 열세를 극복해 이겼다는 것은 이순신 장군의 말씀대로 천행이었다
# : 긍정
# 애국이란 거물 정치인 들이나 들이 지꺼리는 애국타령 팔이로 기생하는 것들이 지꺼리는 것이 아니다 저 백생 저 민초들이 목숨을 다해 지켜온 조국에 아직 친일잔당 외구들이 애국 이라는 이름을 팔아 처먹으면서 득세를 하고 있으니 이순신 장군게서 통탄하실 일이다
# : 부정
# 살고자 하는 자는 죽을 것이요 죽고자하는 자는 살것이다 아직 척이 남아있고 미천한 신하는 죽지 않았습니다 나의 죽음을 적에게 알리지마라 누구나 한번쯤 쉽게 쓸수 있는 말이지만 누가 말했느냐에 따라 그 말의 무게는 달라집니다 한국인은 친절하고 공손합니다 하지만 건들여서는 넘어서는 안되는 사람 두명이 있습니다 한글을 만드신 세종대왕과 나라를 지키신 이순신장군입니다 이 두분을 건들였을 경우 한국인의 오천년간의 전투력을 느끼게 될것입니다 그래서 제발 건들지 말
# : 긍정
# 혹시나 조란탄 이 먼가 하시는 분들을 위해 새알같다고 해서 이름이 조란탄으로 붙여졌는데 정말 탁구공 정도되는 사이즈의 콩알탄 같은 것들입니다 정유재란당시에는 철이 부족해서 돌을깎아서도 사용했다고 하더군요 원거리에서 배박살낼때야 큰 포환을 사용하겠지만 가까이 있을때는 뭐 요즘의 따발총 정도의 효과이기 때문에 살상력이 기하급수적으로 증가합니다
# : 부정
# 아니 명량 척으로 싸운거 고증오류아님 말도 안되잖아 사실 척 다 쫄아서 뒤에있다가 이순신장군이 너무 잘싸워서 승산이 보이니까 뒤늦게 합류했다함
# : 긍정
# 영화 구성기획 다 국뽕코인 탄 영화 한국개돼지 국뽕추종자들이 구성이랑 기획욕하면 매국노새끼라면서 발광떰 그저 그런영화지 이거보다 훨씬 의미있고 심도있게 만들 수 있엇다고봄 그냥 액션활극으로 만들어버렸어
# : 부정
# 쇠주 병 먹을수 있을꺼 같아 이거 보면서 국뽕에 취하듯
# : 부정
# 조선이란 나라 별로 좋아하지 않는데 이순신은 정말 전투의 신 최고중 최고
# : 긍정
# 이렇게 실화바탕 영화를 만들었고 한국에서 흥행했는데 어느나라 특히 일본도 깔 수 없는 게 현실이란거 조상님들 이순신장군님 모두 너무너무 고맙습니다 눈물나네요 나이가 드니
# : 긍정
# 일본인이 가장 무서워하는 전쟁의 신 그리고 백성의 어버이 성웅 이순신 명량해전을 보고 있자니 눈물밖에 안납니다
# : 긍정
# 국뽕 채우러 왔습니다
# : 부정
# 이러니 양궁을 잘하지 않을 수 있나
# : 긍정
# 판옥선이 완전 전함이네 근데 임진왜란이후에 조선은 더 발전할 생각을 안함 양반 선비 천것 타령이나해서
# : 긍정
# 보다가 눈물이 핑도네요 오늘도 감사합니다
# : 긍정
# 나도 후손을 위해 할 수 있는 무언가를 해야겠다 감사합니다 장군님 그리고 같이 싸운 우리 선조님들
# : 긍정
# 그런데 영화가 고증이 멍멍이 판이라 국뽕도 적당해야지
# : 부정
# 올림픽 역쉬 니뽄 괴멸
# : 부정
# 중간중간 아이돌 병사는 왤케 비추냐 몰입이 중간중간 깨지네 계속
# : 부정
# 상유십이순신불사 대한민국의 국운을지켜주신그마음 감사합니다
# : 긍정
# 기억에 남는 장면 일 저격수 토리에타 후리리리리 리 긱 퍽 으아아 아앙아 으아 가아아아아아악
# : 부정
# 명량 영상미 다 좋은데 음악이 아쉽다 불멸의 이순신 음악이 너무 띵곡인건가 백병전할때 아군배가 대포쏘면서 오는 장면에 노래가 너무 심심해 불멸의 이순신 보러가야징
# : 긍정
# 최민식 배우님이 연기한 이순신도 훌륭하지만 진짜 이순신장군님은 김명민이 진리 불멸의 이순신 오래된 드라마지만 지금 다시봐도 김명민 이순신 그자체 이순신장군님 감사합니다 덕분에 자랑스러운 대한민국땅에 잘살게 되었습니다
# : 긍정
# 솔직히 존나 욕만나옴 뭔 고증을 이따구로 했는지
# : 부정
# 척대 척 개뻥이더만 실제로 카이팅 오지게하다가 이길꺼같으니깐 그제서야 나머지 합류했다던데
# : 부정
# 보소 내죽기전에 거북선 뜨는거 볼수있능교
# : 부정
# 된다고 말하게
# : 긍정
# 국뽕 거른다 이기
# : 부정
# 병신같은 국뽕환자들 정신좀 차리길
# : 부정
# 이제 이순신장군님도 지폐로 승급시켜주십시오 언제까지 동전에 뫼실겁니까
# : 부정
# 동물원니까
# : 긍정
# 대신 백청강애기하지말라고
# : 부정
# 교회예수님
# : 부정
# 중국도와줄께요
# : 긍정
# 신에게는 아직 오천만 국민의 응원이 남아있사옵니다
# : 긍정
# 전주이시 이세기들 댐시 나라가 분단 되고 지랄 이네 안그럼 유럽지나서 아프리카 가지 드라이브 여행 다닐긴데 하여튼 개좃같은 세기들이야
# : 긍정
# 일본군들이 불쌍해
# : 부정
# 다시바도 긴장쩐다
# : 긍정
# 무엇하나 잘해준거 없지만 그저 나라가 힘들면 제일 먼저 앞장서서 나라를 위해 헌신하는 백성들
# : 긍정
# 세월호
# : 부정
# 정말 이길거라는 확신이 조금이라도 있으셔서 싸우셨던걸까 정말 여기서 죽겠다 마음먹고 싸우신걸까 진짜 미스테리하고 멋있으시다
# : 긍정
# 어케 이겼노
# : 부정
# 나이가 들어 눈물이 많아졌는지 남자라면 정말 가슴속에서 뜨거운 눈물이 자꾸 나네요 죽고나서 정말 사후세계에서 이순신장군 뵙으면 좋겠음
# : 긍정
# 세울호 빨던 부동산 투기 댓글조작 부정선거 여직원 강간 좌파가 브레인 워시용으로 돌려보던 마스터베이션용 영화
# : 부정
# 두려움을 용기로 바꾸어라 내가 죽어야겠지
# : 부정
# 경상우수사 배설은 저 영화에서처럼 영내 반란을 하지 않았고 명량해전 이후로 병을 핑계 삼아 거짓 휴가를 내고 도주했다 잡혀 죽음
# : 부정
# 개인적으로 박해일 배우도 좋지만 최민식 배우가 아니라면 김한민 감독이 만드는 두편의 이순신 장군 일대기는 김명민 배우가 했었으면 좋았을텐데
# : 부정
# 이 영화의 최고 장점은 실화라는것
# : 긍정
# 영화보고 좀 과장된거 같은데 하고 잘 찾아보니 실제가 더 과장이더라 진짜 대장선 한척이서 저거 다막고 나중되어서 뒤에서 나타남 이거 뭐 말이 안되는 전툰데 진짜
# : 부정
# 이순신 장군의 명량해전 배들이 척 이라고 하는데 척 일수도 있습니다 저도 자세히는 모르겠네요
# : 긍정
# 이건 표현이 안됨 그냥 기적 그자체
# : 긍정
# 액션 씬 인데 눈물이 난다
# : 긍정
# 진짜 좆간지
# : 긍정
# 저 대포를 이순신이 권율한테 빌려줘서 행주대첩 성공
# : 긍정
# 최민식을 좋아하게된 이유
# : 긍정
# 구루지마 진짜 허무하게 사형집행 당했지
# : 부정
# 양궁 세계 위 정리끝
# : 부정
# 줜나 못만든 영화임
# : 부정
# 이순신이 안지켰으면 육지에서 떳어봐 저 많은 군사를 개 될뻔 했네
# : 긍정
# 포브스 선정 가슴이 웅장해진다는 표현이 가장 적절한 영화
# : 긍정
# 대한민국은 반드시 문화 경제 군사 모든것이 일본을 앞설것이다
# : 긍정
# 처음 가까이서 대포쏠때 극장에서 소름돋았었는데
# : 긍정
# 이순신은 비겁자의 영웅
# : 부정
# 웃음 행크주는 코미디 영화
# : 부정
# 이순신 장군으로 나온 드라마와 영화는 언제든 봐도 재미있고 피가 끓게 만듬
# : 긍정
# 아놔 내눈에 흐르는건 땀인가
# : 부정
# 이순신 장군은 척의 배로 일본군 척의 배를 침몰시켰다 전략이 뛰어난건지 기적인건지 아니면 둘다 인건가
# : 부정
# 김명민이 이순신이야 아니다 불멸의이순신은 그 사람 밖에 떠오르지 않네 그려
# : 긍정
# 근데 난 아직도 이영화 안봤다 관객수 실화
# : 긍정
# 이영화는 국뽕이라 할 수가 없음 왜냐면 영화자체가 존나 너프먹였기때문
# : 부정
# 대한민국 역대급 카리스마 짱은 이순신 장군님
# : 긍정
# 작은 한국은 절대 굴복하지 않는다
# : 긍정
# 어떻게 용기로 바꿀 수가 있겠습니까 죽어야겠지 내가 모든 민주 시민들이여 촛불시민들이여 이순신 장군의 용기로 적폐수구 친일세력을 무찌르고 선진 민주 복지 부국으로 나아갑시다 대한민국 만세
# : 부정
# 이래서 우리나라가 양궁을 잘하네
# : 긍정
# 이래서 지도자 한명의 역할이 중요함
# : 긍정
# 영화에서는 일본 해군은 전방이 털리니 바로 철수하는데 실제로는 조선 해군이 일본 해군 함대의 최후미까지 침투하여 무려 일본 함대 총사령관 도도 다카도라의 손바닥에 화살을 꽂아버렸다고 합니다 영화상에서 나온 것도 엄청 대단한데 실화는 더더더욱 비교가 안되게 대단
# : 긍정
# 저 당시 거북선은 증기선이었다 입에서 연기가 나왔다는 건 독가스가 아니라 증기선이었다는 증거다 만약 독가스면 우리 아군도 다 피해보는데 애당초 말이 안 되는 얘기다 그 다음 증거가 엄청난 함선 마력인데 다섯 척이 척 사이를 뚫고 돌격하려면 노꾼 힘만으로는 설명이 안 되는 파워다 한참 전투중이면 적군 한 척만 밀어내는 힘이 아니라 최소 세 척 많게는 열 척 이상을 단번에 밀어낼 수 있는 힘이 있어야 가능한데 그런 함선 파워도 없이 함선 숫자가 열 배 이상
# : 부정
# 저렇게 백성들이 보는 앞에서 직접 왜군을 말도 안되게 물리쳐버렸으니 그 옛날 장군들의 위세가 얼마나 대단했을지 짐작할 만하다 왕이 괜히 이순신을 시기질투해서 가둔 게 아니었어
# : 긍정
# 신기한게 일본사람들 역사왜곡엄청 하면서 이순신장군은 이름 다 알고 아직도 무서워하고 기리는 이도 있다는 게 얼마나 대단하셨으면
# : 부정
# 정말 너무 감사합니다 대한민국을 지켜 주어 우리가 대한민국에서 살고 있다는 것을 너무나 감사합니다
# : 긍정
# 장경철 멋지다
# : 긍정
# 그져 감사합니다
# : 긍정
# 이순신 장군님이 위대한 분이라는 것은 말할 필요도 없고 우리나라의 배 기술도 대단함을 느껴야 함 판옥선은 밑이 평평해서 제 자리에서 회전이 가능하고 못을 사용하지 않은 공법 덕에 소금물이 들어가면 더 견고해진다고 들었음 게다가 크고 튼튼해서 화포를 싣고 사용 가능함 그러나 일본배는 빠르게 움직이기는 좋으나 작고 약함 소금물에 닿으면 더 약해진다고 함 어쨌든 배에서 화포를 사용할 수 없는 구조라 빠르게 이동해서 적의 배에 올라타 백병전을 주로 하는 전술을
# : 긍정
# 나라를 지켜주신 장군님과 위인들에게 경의를 표합니다 감사합니다
# : 긍정
# 이순신장군님의 컨트롤 시즈탱크하나로 얼마나 많은 저글링을 잡으며 버티신겁니까
# : 긍정
# 아프겠다
# : 긍정
# 내같은기운을 가진사람이 군인이 되야 맞는건데 형배야
# : 긍정
# 이때도 우리나라가 배를 더 잘만들었다
# : 긍정
# 선우야
# : 부정
# 에이 실제로는 백병전이고 뭐고 혼자서 그냥 일방적으로 뚜들겨 팼다고 하던데 영화라서 긴박한 장면이 필요했나 하긴 이래도 저래도 알면서도 못믿겠다 알고 있는 나도 못믿는데 모르는 사람이 보면 이거를 믿느니 차라리 파타지 소설에 드래곤을 믿지
# : 부정
# 징글징글한 일본것들
# : 부정
# 상유십이 순신불사
# : 긍정
# 쌓인 원한을 우리시대서 천배만배 갚아줄것입니다
# : 부정
# 스님 언월도 개쩐다
# : 부정
# 고맙습니다 이 순신 장군님
# : 긍정
# 날씨가더울때마다본다 시원한해전
# : 긍정
# 더이상갈곳도 물러날곳도없으니 죽을힘을다해 싸울수밖에 이순신장군은 최강이다
# : 긍정
# 저 시대의 선조 문재앙
# : 긍정
# 일본넘들아 다시한번 오너라 그때는 후지산화산에 현무 미사일 폭격해주마
# : 부정
# 이순신 이거 정약옹이 만든거야 이 개자식들아
# : 긍정
# 실질적으로는 대 임 나머지 놈들은 뒤에서 죽기싫어서 지켜봄
# : 부정
# 역시 이순신
# : 긍정
# 개씹 역사 왜곡물
# : 부정
# 중공인민해방군이 서세동점시기에 해방된 농노들로 대한인은 대륙의 황족들로 한반도로 이주됩니다 조선왕조실록 의 기록 순조실록 권 순조 년 월 일 정미 번째기사 년 청 가경 년 전 통제사 이당을 소견하고 통영의 폐단에 대해 순문하다 거북선이 있는가 없는가 하니 이당이 말하기를 있습니다 그 모양이 거북같이 생겼는데 천여 명을 수용할 수 있습니다 그리고 노 없이 바다에 떠다니는 것이 마치 거북이 떠 있는 것 같으며 입과 코에서 연기가 나오므로 지금도 표류 해 온
# : 긍정
# 백병전을 준비하라 멘트다음 장면에서 스님 포스가
# : 부정
# 오늘 일본 도쿄에서 올림픽 덕에 애국가가 울려 퍼졌다
# : 긍정
# 새롭게 알게된 사실 척이 아니라 사실은 이순신장군의 배 척이였다는 사실 나머지 척은 미적거리고 보고만 있다가 전세가 유리해지자 그떄부터 정말 소름이다 이순신 장군
# : 긍정
# 우리 조상님께 항상 감사함을 느낍니다
# : 긍정
# 몇번을 봐도 소름끼치는
# : 긍정
# 진짜 전설이야 척으로 어떻게 이겨 드라마도 이렇게하면 막장이라하지 이순신 장군님 존경하고 감사합니다
# : 긍정
# 개인적으로 이순신장군 연기는 김명민이 잴 좋았다
# : 긍정
# 명량대첩 전에 이순신장군이 작전에대해 고심하고 있을때 꿈에 산신령이 작전을 가르쳐 주었다는 전설이 있는데 사실 일까요
# : 긍정
# 전쟁이 결코 나라에게는 불행적인 일이다 하지만 일본과 만약 전쟁을 다시한다면 이순신장군의 마음으로 절대 일본에게 지지 않을것이다 후배들이여 그대들은 절대 후세들에게 치욕적인 미래를 선물하지 말기를 바라고 바란다
# : 긍정
# 실제 대장선 혼자 싸운겁니다 안위 김응함은 나중에 싸웠고 나서지는 끝날 무렵에 숫가락 얹은 거구요 명량은 대 이 정확합니다
# : 부정
# 이순신 장군이 이 대 으로 싸울때 원균은 종이배로 싸운건가요
# : 긍정
# 존경 또 존경스럽다
# : 긍정
# 이순신 배역에 걸맞지 않았던 점이 최대 악수였다 목소리도 변조시키고
# : 부정
# 반대 누른 대깨문들은 뭐냐 대깨문도 모자라 친일하는 짓거리 보소
# : 부정
# 장면 하나하나는 멋진데 어째 편집 시간흐름이나 중간연결 장면이 빠진듯한 연출 슬프다 조금만 더 잘 만 들던가 편집이라도 잘 하던가 배우들 촬영스텝 넘 잘했는데 감독 역량 부족 잘 찍고 완성도가 모자란 듯
# : 부정
# 미국에 아이언맨이 있다면 우리에겐 거북맨이 있다
# : 부정
# 영웅은영웅인데 조선정부에서는 영웅대접하기가 고려는 영웅 강감찬 년 전쟁을 끝낸분의 대접부터가 달랐슴 두분다 공통점은 나라위해헌신했지만 반대의길로 감 하기사고려의 군조직이 중앙군 군 위에 지방군인 주진군 주현군을 두어서 장비빼고 고려가 나았다는 웃긴건 무신을 개차반취급하다 무신정변일었났지만 영웅을 어떻게 그릇에 담느냐가 차이였슴 고려와 조선은
# : 부정
# 난세의 영웅이십니다 그러나 현재도 정치는 쓰렉입니다 죄송합니다
# : 긍정
# 난중일기속 명량해전 일 맑음 이른 아침에 망군이 와서 보고 하기를 적선이 무려 백여 척이 명량을 거쳐 곧바로 진치고 있는 곳으로 향해 온다 고 했다 여러장수들을 불러 거듭 약속할 것을 밝히고 닺을 올리고 바다로 나가니 적선 백 여척이 우리의 배를 에워쌌다 지휘선이 홀로 적선 속으로 들어가 포탄과 화살을 비바람같이 쏘아 대지만 여러 배들은 바라만 보고서 진군하지 않아 일을 장차 헤아릴 수 없었다 배위에 있는 군사들이 서로 돌아보며 놀라 얼굴빛이 질려 있었
# : 긍정
# 천만관객이라는 명성을 얻기에는 확실히 부족한 영화 다들 이거 왜 봤었지 이때 뭐 사회적 으로 사건이 있었을 때인가 별것도 아닌 영화인데 너무 화제되고 흥행도 성공함
# : 부정
# 저때 왜넘들이 판옥선에 오르는거 자체가 불가능하지 않았나요
# : 긍정
# 대장선이 앞장선다
# : 긍정
# 행배야 되았다 고마 드가자
# : 부정
# 군신
# : 긍정
# 이렇게 피흘리시면서 지켜내셨는데 어떤 대선 후보 녀석은 일본 찬양하기에 바쁘니 한심하다 제발 정신좀 차려라
# : 부정
# 진짜 전략이 좋았음
# : 긍정
# 거북선은왜없지
# : 부정
# 참으로 꼴보기싫다 어떻게 사상이 불순하놈이 감히 이순신장군으로 나오는가 이를 학생들이 볼것을 생각하니 개탄스럽다
# : 부정
# 몇번씩 다시 보지만 효과나 분장이나 복장등 완성도가 높은 작품
# : 긍정
# 맨날 헬조선 그러고 이럴때만 우리나라
# : 부정
# 이때 졌으면 그냥 일본에 흡수돼서 길거리에 애니메이션 노래나 질질 세어 나오고 동경대 본캠에 시험보러 간답시고 매년 비행기 타는 고 들이 수백 수천명이었겠지 그렇게 지켜낸 한국인데 아직도 헬조선에서 벗어나질 못하고 있다
# : 부정
# 척 척 불가능한 전쟁을 이순신 장군님이 해냈습니다 명량해전 기억합시다
# : 긍정
# 연기를 넘 잘한다 몰입 됨
# : 긍정
# 이순신은 정말 한민족 역사상 최고의 성웅이신 하늘이 조선을 구하기 위해 내려보낸 장수라고 해도 과찬이 아닌 무패의 신화 다만 이 영화 보면서 아쉬웠던 부분은 고증이 참 극장서 보면서도 혀를 찼던 장면이 이 백병전이었네요
# : 긍정
# 이순신장군 저 순간 얼마나 힘들고 두렵고 고독했을지
# : 긍정
# 실제 승려들이 전투에 참여했는지 모르겠는데 승려들 전투신들이 멋졌다고해야 하나 전투신은 하나하나 묘사를 다 잘한듯
# : 긍정
# 어디서 본 건지 모르겠는데 배 척으로 싸웠다고 함 그리고 나중에 나머지 배들을 투입시켰다고 들었음 나랑 똑같은 이야기 들으신분
# : 부정
# 추석 특선 영화로 명량 해도 괜찮을 듯해요
# : 긍정
# 이순신님이 무서워서 우는것은 답 힌트 으로 가족이 다 죽음
# : 긍정
# 전군 출장하라
# : 부정
# 이순신은 애초에 지는 싸움은 하지도 않았다던데 척으로 저 해역에서라면 이길 수 있다고 생각했다는거 아냐 개쩌네
# : 긍정
# 척이라고 하는데 실제로는 척으로 다 발라버린 전투임 거의 이길때쯤 되니깐 나머지 척이 슬슬 숟가락 올린거임 그래도 참 대단한게 척으로 저 수백대 되는 일본수군을 버티고 압살하다니 아직도 전세계 미스테리 해전임
# : 부정
# 그냥 미친거임
# : 부정
# 외적 침입에 대한 국가 반성은 없고 한 인물 영웅전으로 끝나 버리는
# : 부정
# 유성룡씨 목을
# : 부정
# 아니 예전부터 궁금했는데 이거 무슨뜻임
# : 부정
# 어떻게 지킨 나라인데 후손들이 잘 해야 합니다
# : 긍정
# 이순신 장군님은 언제나 우리 맘속에 살아 숨쉬고 계심니다 감사합니다
# : 긍정
# 전세계가 인정한 영웅 이순신 존경합니다
# : 긍정
# 중국 놈들 봐라 일본놈들이야 뭐 이게 대한민국이다
# : 부정
# 부처님의 힘을 받은 승병이 짱이지
# : 긍정
# 우리조상님들은 이러셨는데 일본인보다 더일본을 사랑하는 이들이 있으니 어찌 해석해야 하나요
# : 긍정
# 우리 대한민국 전 국민은 이순신 장군에게 빚을 졌다 다시는 일본 따위에게 지지 않겠다 뿐만 아니라 꼭 한번은 일본을 치겠다 우리 조상의 이름으로 꼭
# : 긍정
# 저 색끼들은 왜 늘 남의 나라를 침략하는걸까
# : 긍정
# 개인적으로 극장에서 가장 기억에 남았떤 장면들 진짜 멋있고 통쾌하면서 완전 소름
# : 긍정
# 오 소용돌이에서 백병전이라 왜 캐리비안의 해적 세상의 끝에서가 연상되는건지
# : 부정
# 이성게세기 이방원 관심없고 난 우리의 이순신 황제 페하만 관심잇다 잡것들 조선 전주 이시시발넘들 조선이 우리에게 남긴건 나라를 조선 처럼 경영하면 망한다는 사실을 알려준거 박에 없다 게시발 세기들
# : 긍정
# 이방원세기는 좃대가리가 센티그래서 좃나게 떡칠을 쳣다고 그래서 살에 쳐디젻다네
# : 부정
# 저걸 발견하고 활로 맞춘 장군도 대단하다
# : 부정
# 국뽕이라해도 좋다 아 좋다
# : 긍정
# 척이 아니라 이순신장군의 대장선 혼자서 막은거
# : 부정
# 단군할아부지가 내려주신 선물
# : 긍정
# 마법의 주문
# : 부정
# 이순신 장군님 감사합니다
# : 긍정
# 이건 국뽕을 넘어섰지 소설도 아니고 실화인데 전세계에서 이정도의 스펙타클한 실화 있냐 진짜 이순신장군 세종대왕은 전세계에서도 정말 넘사벽이지
# : 긍정
# 왜군 숫자를 보고 얼마나 무서웠을까 그 당시의 병사들의 마음을 생각하면 마음이 아프지만 이순신장군님과 다른 장군 병사들이 그 두려움과 왜군과 맞서 싸운 덕분에 지금 우리가 이렇게 대한민국에 살고 있고 그에 정말 많이 감사드린다
# : 긍정
# 이순신은 일본에서도 신으로 추앙받는 조선의 명장이다
# : 긍정
# 대한민국배우들 진짜멋있습니다 고맙습니다
# : 긍정
# 살고자하면 필히 죽을것이고 또한 죽자하면 살것이니 와 명대사
# : 긍정
# 충무공이 위대한건 외부는 외부대로 내부는 역대최악 무능인 선조를 상대로 내부대로 전부 잘 싸워왔단 거다
# : 부정
# 허용되는 국뽕
# : 부정
# 저때면 승자총통으로도 싸웠을텐데 안나온게 아쉽다 요즘 새로운 설에 의하면 조선수군 싸움 방식이 근접해서 조란환 산탄으로 갑판 적병력 쓸어버리고 적배에 올라타서 백병전으로 쓸어버리는 전투 방식이었다던데
# : 긍정
# 백병전은 없었다
# : 부정
# 이순신 장군님 감사합니다 하지만 영화상에 문제가 있습니다 역사에 기록되있는 정확한 배의수는 척 입니다 그래도 재미있게 봤습니다
# : 긍정
# 고증대로였으면 너무 재미없을듯 해서 없던 백병전 넣었다던 실제로는 일본 군함이 아예 접근도 못하고 박살났다고 하죠 실제가 영화보다 더 레전드
# : 부정
# 볼수록 화나게한다 선조는 임금이 맞나
# : 부정
# 픽션으로 만든 아이언 배트맨 스파이더맨 캡틴아메리카 보다 더 픽션같은 이야기 하지만 실존했던 히어로 믿기지가않는다
# : 긍정
# 이새대에 이런 장군이 나와야하는대 참으로 존경합니다 이순신 장군
# : 긍정
# 년에 번씩 난세에 영웅이 탄생 하는구나
# : 부정
# 오죽하면 적국이었던 일본에서 아직까지도 이순신을 존경하는 사람이 있을까 여러 설이 많지만 엄청난 명장이었음은 틀림없다
# : 긍정
# 전세계 어느장군이 아무리 지형적이점을 감안한다고해도 척을가지고 척을 맞써싸울 생각을 할까
# : 긍정
# 솔직히 고증 엉망에 실제 역사랑 안맞는 부분이 많아도 전투씬은 잘 만든게 맞는듯
# : 긍정
# 왜 이런 답글에는 친일들이 댓글을 달지 않는가 일본 찌끄레기새끼들
# : 부정
# 제발 후속편은 일본어는 쓰지 말자 진짜 일본인이 더빙을 하던가 만일 일본영화에서 일본인이 한국인 역을 하는데 발음이 그래쓰무리다 감사하무리다에 억양까지 박살내면 몰입도 떨어지고 개그화 되잖아 일본장수 역할한 조진웅 등 발음이 그래 진짜 일본인이 더빙을 했으면 정말 영화는 보고 또 봐도 전율이 흐른다 일본어 사용만 제대로 해서 완성도를 높이자
# : 부정
# 근데 이후 조선의 행보를 보면 이순신이 크게 아쉬워했을 것 같음
# : 긍정
# 저는 김한민감독을 별로 좋아하지 않습니다 저는 아무리 영화라하지만 충무공 이순신장군을 이렇게 비하하는 영화로밖에는 보지 않습니다 실제 그대로도 성웅이신데 말도 안되는 판타지로 오히려 충무공 이순신장군을 폄하하는 것 같아요 이번에 노량해전인가 만든다고 하는데 저는 이런식이면 절대 반대입니다 역사기록에도 충파 백병전의 기록은 찾아볼 수 없습니다
# : 부정
# 살짝 편집이 아쉽네요 충파다 구선이 부활했다 구선이 부활했다 노인양반의 멘트를 넣어줬으면 더 극적이었을텐데요
# : 긍정
# 기다려라 한산은 끝났고 박해일 노량은 김윤석 촬영중이다 이 영화 이순신장군님으로 인해 대한민국은 다시 하나가 될것이다 성웅은 하늘로 가신지 수백년이 지났지만 언제나 나라와 백성들을 지키고 보살펴 주신다 작은 민초 백성으로 번번히 염치없고 뵐 면목이 업고 부끄럽지만 장군님은 늘 그렇게 나라와겨레를 보듬어 주신다 시간들 되시면 가족들 데리고 아산에 충무공묘에 참배라도 다녀오심 좋겠다 그저 항상 죄송하고 감사한 마음뿐이다 고맙습니다 장군님
# : 긍정
# 일본은 이순신 장군님을 결코 잊지 못할 것이다
# : 긍정
# 압도적으로 불리한 전력차를 사기적인 자연의 힘을 빌려 왜군을 부셔버렸다
# : 긍정
# 원레는 척이였지만 나중에는 다 쫄아서 도망가고 결국 충무공 이순신의 배만 남았으니 배 한척과 척의 싸움이네요 우리가 지금까지 살아올 수 있는건 이순신 장군님과 다른 순국열사님들의 희생과 노력으로 쌓아온 지금이 아닐까 생각해봅니다 그러니 여러분들도 하루하루를 열심히 살아가야해요 우리가 누리는 그 하나하나의 하루가 다 장군님 순국열사분들이 만드신 지금이니까 우리가 지금 귀찮게 살고있는 오늘은 돌아가신 분들이 원하던 내일이니까요 이 글이 조금이라도 도움이 되
# : 긍정
# 신에게는 아직 천만 국민들의 응원과 지지가 남아 있사옵니다 보고 왔습니다
# : 긍정
# 저분은 지금 비록 역사에 기록 되었지만 전설같은 분
# : 긍정
# 오만원권 인물을 당장 성웅 이순신장군으로 교체합시다
# : 부정
# 그냥 편하게 이해하자 스타로 치면 드라군 부대가 저글링 부대를 이긴 셈 마리가 아니고 부대
# : 긍정
# 상유십이 순신불사 신에게는 천만 국민의 지지와 응원이 있사옵니다
# : 긍정
# 일본은 조선배보다 한 배나 더 많으면서 졌네 역시우리조선 이순신장군의 살고자하면 죽을것이고 죽고자하면 살것이라는 말과 걱정을 용기로 바꾸는말들이 이결과를 만들어낸것이다 이순신장군
# : 긍정
# 스님 언월도 진짜 개멋있다
# : 긍정
# 최민식님 최고의 영화중 하나 다른 조연배우들의 연기도 대단했음 의심할 여지 없이 내가 본 최고 영화중 하나
# : 긍정
# 대부님 자랑스럽습니다
# : 긍정
# 감동 마지막 먹을수 있어 좋구나 나도 그렇게 늙고 그렇게 죽고 싶다
# : 긍정
# 마지막 전투 한산도 대첩도 영화 만들어서 이순신 장군의 마무리영화로 최종의막를내렸으면 좋겠네여
# : 긍정
# 진짜 감사합니다 덕분에 지금 우리나라가 존재하는것 같습니다
# : 긍정
# 난 이장면 너무 좋아 이순신 장군이 전쟁 준비 때 활 연습을 엄청 시켰서 거의 다 명사수였을듯
# : 긍정
# 이 장명 볼때마다 소름 돋고 가슴이 뜨거워진다 이보다 더 강력한 리더쉽 없다고 봄
# : 긍정
# 가슴이 더욱 웅장해진다
# : 긍정
# 전군 출정하라 대배우만이 낼수 있는 짧은 대사의 강한느낌
# : 부정
# 나라를 살리려는 분도 계시고 나라를 망치려는 분도 계시고
# : 부정
# 장군 님 부끄럽습니다
# : 부정
# 일본군 진짜 플래그 오지게 세웠네
# : 부정
# 넬슨이랑 비교하지 말라는 외국 다큐 있던되 어느나라인지 몰라도 해군사관학교 교과서에도 나오고
# : 긍정
# 영화보니까 나는별로재미없던데 뭐 한 번봤나
# : 부정
# 충성
# : 긍정
# 효모찌당신은잘못알고있어요부화가아니라동료예요
# : 긍정
# 명절 특선 국룰
# : 부정
# 백성들 나서서 노 저어줄 때 감동이다 눈물 나네
# : 긍정
# 어떡해 나 울 것 같아
# : 긍정
# 와 이렇게 많은 배들을 척으로 물리치다닛 이순신장군님은 신이다
# : 긍정
# 한국 보수 우파들이 이순신 장군님 싫어 하는 이유를 잘 설명해주는 동영상
# : 긍정
# 다시 봐도 싫다 적어도 차이나식 갑주에 귀선인데 구선이라하고 이순신장군을 하필 저 배우가 그냥 위인 팔이지 이건 내가 명량에서 기대했던 이순신장군이 그대로 재연되어 나타나길 원했는데 이 전에 봤던 류 일본 영웅 영화가 떠올릴 정도로 별로였음 그리고 귀선이야 귀선
# : 긍정
# 저 때 이순신 장군의 나라 뒷 배경을 알면 차올라 넘치던 국뽕 다 시글어 듦
# : 부정
# 아이구 스님이 아니고 관우인줄 은월도르가지고 휘두르시네
# : 부정
# 난 이정현 벙어리역으로 치맛자락 휘두르면 울부짓는 장면이 어찌나 가슴아프던지
# : 부정
# 명량에서 대 이 아니라 대 의 무쌍을 찍었지요 혹자는 이라고 이야기 하는데 겁에 질려 불알까지 쪼그라들어서 전투에 임하지도 않았든 배는 그냥 뺍시다 김억추 새끼
# : 부정
# 악마를 보았다 보고 오니까 집중이 안되네 허허
# : 긍정
# 네 구라 쳐깐거구요 이순신역할한분님 너무멋져요
# : 긍정
# 저 때나 지금이나 기회주의자들 때문에 나라가 위태로움 같이 싸워야지 말싸움이나 하고 해보지도 않는것들
# : 긍정
# 심지어 고증 그대로 지키면 너무 압도적으로 이기니까 최대한 상황을 어렵게 각색했음에도 비현실적이라고 느껴질 정도라니 대단합니다
# : 부정
# 고슴도치냐
# : 부정
# 비켠진최뢰
# : 긍정
# 우선 안나오지 고물상
# : 부정
# 나는 아랍인이지만 을 존경하고 감사합니다
# : 긍정
# 근데 전쟁은 이겼는데 처음에 집 건물 다 태운건 어떻합니까
# : 부정
# 이순신 테란의 황제 구루지마 아마추어 스타 선수
# : 부정
# 조란탄 터지는 장면은 몇십번을 봐도 통쾌함 정말 멋짐
# : 긍정
# 와키사카 바보
# : 부정
# 나이수 시
# : 부정
# 이순신의 대장선 혼로 사투를 벌이다가 안위 등 척이 가세했고 물살이 바뀌어 전세가 뒤집힐 때쯤 나머지 척이 도우러 왔고 김억추 척은 끝까지 항전하지 않았다고 합니다 판옥선 척으로 오는 족족 부셔가며 무쌍을 찍기 시작하며 승기를 잡기 시작했다고 합니다 일본은 못해도 척 이상의 침몰 척 이상의 대파되었고 만 이상의 전사자가 발생하게 되었다고 합니다 좋은 영상 감사합니다
# : 부정
# 난 솔직히 영화 명량보다는 불멸의 이순신이 더 나았다고 본다 둘다 고증이 왜곡된것에선 벗어날순 없지만 최민식보다는 김명민이 이순신에 더 잘 어울렸던것같다
# : 긍정
# 이 장군님을 같은 과학기술로 되살려낼수만 있다면 이 영화 보여드리고 싶음
# : 긍정
# 불교 얕보지마랔
# : 긍정
# 명량해전 초기 까지만해도 이순신 장군 혼자 싸웠다 해도 모자람 없었음 다른 조선수군은 무서워 접근도 못하고 그러다가 이순신 장군 혼자 일당백으로 싸우는 모습 보고 조선수군도 용기내서 조금씩 움직여 싸웠고 아무튼 명량해전 대승은 이순신 장군이 없으면 꿈도 못꿨음
# : 긍정
# 영화에서는 도도다카도라가 안전하게 돌아갔지만 실제로는 부상으로 장계조차 쓸수 없었다 그래서 그의 부하가 대신 장계를 올렸다 실록이나 고산공실록 기록을 보면 일본군 다수 이상이 죽었다는데 영화에서는 대부분 안전하게 돌아간거 처럼 그리고 실제로는 보급을 못받아서 철탄이 별로 없었음 돌을 둥글게 갈아서 돌탄으로 상대했음
# : 부정
# 일본은 조선에 대해 모든 걸 조사를 했지만 가지를 간과하고 조선을 공격해 전쟁에서 실패 하였다 조선에서 가장 천대 받던 자들이 나라를 죽을힘을 다해 지킬줄 몰랐고 이순신의 존재를 몰랐고 무엇보다 일본이 엄청 빠른 시간에 한양을 점령했지만 빛의 속도로 나라와 백성을 버리고 도망간 임금이 있을 준 몰랐다
# : 긍정
# 아직 보는 사람
# : 긍정
# 가장 확실한건 이순신에 대한 두려움 트라우마가 발목을 잡았을것이다
# : 부정
# 님들아그거알아 지금싸우고잇는이순신장군님이업섯스면우리나라실래로일본한태정렴당햇슬거야하지만한국인승리
# : 긍정
# 역시 우리나라가 짱이야
# : 긍정
# 역사적사실인데도안믿긴다 진짜 전쟁의신이라고밖엔
# : 긍정
# 이순신은 존경하지만 이 영화는 싫어한다 스크린쿼터제를 외치던 년전 생각은 못하고 스크린독점해 상영관 개중 개가 명량 개가 가오갤인걸 보고 위인을 그리며 상영하지만 영화계는 얼마나 지저분한지 알았다 몇달을 기다렸던 영화는 시간을 달려서 보고왔다
# : 긍정
# 포방부는 고려떄부터 이어져오던 전통이지 군사제도가 농병일치라 상비군이 조또 없어서 발린거지 무기수준만 놓고보면 포대 총이라서
# : 부정
# 척의 이지스함
# : 부정
# 저런 리더쉽이 필요한 현제 대한민국
# : 긍정
# 길이남을 명작이야
# : 긍정
# 자기 배보다 약 배나 큰배가 앞에서 전속력으로 다가오는데 레알 저표정 안나올수가 있냐고 조선시대 판옥선은 탱크네 완전
# : 부정
# 우리 나라 최고의 장군 정말 풍전등화의 나라를 구한분
# : 긍정
# 참내 이순신 장군님은 이렇게 무식한 싸움을 하신 적이 없어 대장선이 왜군 함선을 개박살 내는 동인 단 명의 사망자와 수 명의 부상자만 있었을 뿐이다 이게 실제다 무슨 조선 수군이 전부 무림 문파의 장로급이냐 저런 말도 안되는 백병전만 영화 내내 줄곧 고뇌와 고민을 거듭하고 거듭하셔서 위치의 선점과 조선군이 가진 기술의 우위를 이용해 철저하게 적의 접근 자체를 틀어막고 화포와 화살로 적을 아예 작살내셨지 이렇게 운빨과 개인의 무력에 전투를 의지하신 분이
# : 긍정
# 한산 언제개봉함
# : 긍정
# 한가지 아쉬운건 이순신이 전라좌수사가 아니라 경상 우수사나 좌수사가 됬었으면 임진왜란이 그렇게까지 피해를 입지는 안았을텐데
# : 긍정
# 근데 이순신 없었으면 진짜 조선 망했겠죠 저떄 일본의 수륙병진 작전이 그대로 진행됬을테니까
# : 부정
# 웅장하고 멋지다
# : 긍정
# 거북선 돌진
# : 부정
# 그 어떤 영화 장면보다 가장 멋있다
# : 긍정
# 이순신 장군님 눈물이납니다
# : 긍정
# 한 번 본거 같은데 항상 볼때 마다 소름이 돋네요
# : 긍정
# 안싸우고 존나 도망다녔다는데 무슨 성웅 헤세바르텍 조선 여행기 하멜표류기 영국 왕실 여행기의 공통점 길거리 오줌 똥 천지이며 그 똥을 개가 먹으며 그 개를 사람이 잡아 먹는다 그들은 무지막지한 고봉밥을 고추 한줌에 밥을 비운다 길도 제대로 없어 수레바퀴를 끌 수 없어 바퀴가 없는 가마를 들고 다녀야 한다 년대 말에 영국이 지하철 개통했을 시기
# : 부정
# 아 국뽕이 차오른다
# : 부정
# 근데 만약 실제로도 저렇게 백병전이 계속 진행됐으면 패배했을것임 왜병 한명만 갑판에 올라와도 엄청난 위기였음 그만큼 조선군은 단병접전에 쥐약이었고 일본군은 엄청 강했기 때문 영화에서는 일본 배가 그냥 전부다 판옥선에 배 붙이고 널빤지만 대고 건너는걸로 보이지만 실제로 일본군의 주력 함선이었던 고바야와 세키부네 고바야는 판옥선에 비하면 뗏목 수준이었고 세키부네 조차도 판옥선에 비해 매우 작아서 배를 대도 널빤지가 아니라 사다리를 대고 타고 올라가야 할 정
# : 부정
# 아재 코어힘이 어마어마하시네요 데드 원알엠이 어떻게 되시는지 궁금해집니다
# : 긍정
# 극장에서 초부터 포소리가 예술이였는데
# : 부정
# 저게가능 의 시초이신 성웅 충무공 이순신장군
# : 긍정
# 지금 회차입니다 갑자기 생각난 건데 고경표님의 역할이 뭐죠
# : 긍정
# 영화에서 안위한테 했던 대사는 실제로는 중군장 김응함에게 했던 말입니다 때 등장했던 분들은 해상의병일 가능성이 높습니다 실제로 명량해전때도 해상의병들이 제공해준 어선들을 이용해서 아군쪽의 배가 많아보이도록 위장술을 펼치기도 했다고 합니다
# : 부정
# 국뽕이긴한대 가슴이웅장해진다
# : 긍정
# 개시발련들 전쟁 좀하지마라 역사책 두꺼워지잖아
# : 부정
# 영면하십쇼 장군님 정말로 감사합니다
# : 긍정
# 장군님 엔드게임이었네요
# : 긍정
# 왜 명량대첩이아닌 명량해전으로 분류되어있을까 왜 세계 대 해전에는 명량해전이 없을까 대 해전을 통해 전술을 배워야되는데 이건 불가능 하거든 역사학자들의 속 마음을 좀 상스럽게 표현하면 아니 이게 가능해
# : 긍정
# 된다고 말하게 이마인드가 진짜 사회에서도 중요하지
# : 긍정
# 일본배들은멌지고간지나는데 왜이렇게부실하고나약하게생곁냐
# : 부정
# 막타 치치러 오네
# : 부정
# 너무너무너무 감사합니다 다시한번감사합니다
# : 긍정
# 여기 댓글 수준도 굿이네
# : 긍정
# 실제론 왕이 척의 배로는 해전에서 적이랑 싸움이 안될테니 이순신에게 육군에 합류하라 지시하여 육지에서 막으려 했답니다 그 내용이 담긴 편지를 받고 이순신이 답하길 제게 오히려 적을 막을 배 척이나 있습니다 오히려 라는 말은 대체
# : 긍정
# 매드무비 상상함 현실 고슴도치
# : 긍정
# 북한 일본은 대한민국의 주적 이다
# : 부정
# 진심 온몸에 전율이 돈다
# : 긍정
# 후손들이 너무 죄가 큽니다 애국심의 심장이신 이순신장군님과 선조님들 사랑합니다
# : 긍정
# 이런 우리들의 조상님들이 있으니까 지금 이렇게 편하게 사는거야 죽어야 겠지 생각 말고 어떻게든 살아야지 이런 생각이 든다
# : 긍정
# 국뽕이 네 발부터 머리 끝까지 차오른다
# : 부정
# 한국인의 단합력은 이때부터인가
# : 긍정
# 울돌목 아래 물길을 막은 바위덩어리 콘크리트 덩어리 꺼내서 세계적인 관광지로 거듭나면 좋을것 같은데
# : 긍정
# 이순신장군은 지금 이 시대에도 절실히 필요한것 같아 씁쓸함 난세에 영웅이 나와야 할터
# : 부정
# 그는 영웅이 아닙니다 하늘에서 내려준 신입니다
# : 긍정
# 국뽕이다 카는 이딴말하지마라 어느 안전이라고 그딴 소리를 지끼나 말이다 진정 이 땅에 숨쉬고 목구녕으로 물과 밥을 넘기고 사는 사람새끼라면 아무리 못배웠어도 적어도 이순신 장군님의 동상앞에서 묵념이라도 하는게 짐승이 아닌 사람새끼가 할 기본 예절일것이다
# : 긍정
# 학교 역사시간에 이런거 틀어주면 애들 아또야 걍 자야지 수업끝날때쯤 쌤 자 이제 끊다 애들 아 쌤 이것만
# : 부정
# 막말로 최민식 이순신 빼면 뭐가 남냐 이순신 장군을 제일 존경하는 입장에서 명량은 이순신이라는 위인에 대한 모독으로밖에 안보인다
# : 부정
# 이순신을 죽이려고 한 일본군에 최후
# : 부정
# 크 이순신 장군님 대단하시다 잔인하다
# : 긍정
# 아니 중간에 여자분 왜저렇게 소리치는거임
# : 부정
# 우리나라의 전설중에 제일대단하신 이순신 장군님 정말로 감사합니다
# : 긍정
# 영화 명량 스토리 대부분이 허구인건 아시죠 화폭선 이후에 적 본대가 이순신에게 다가올 때 물살이 바뀌어서 살수 있었던 천운 그게 말이 안돼요 근데 이게 설명이 안돼요 을 이겼다는게 구라 같지만 우리나라 서적에서도 찾을 수 있고 일본 서적은 더 자세하거든요 우리가 이긴건 일단 맞아요 근데 어떻게 이겼는지를 표현하는데 천운을 포함해도 어리둥절 할 정도로 말도안되게 이겼는데 저 천운이 없다는 실제 전투는 진짜 어떻게 풀어나갔는지 이기는게 말도안되는 전투 입니
# : 긍정
# 이런거보면서 감동하면서 왜 지금 군인들은 인정을 안해주는걸까
# : 긍정
# 힘이 잔뜩 들어간영화 영화관이서 보다 졸았던 기억이
# : 부정
# 어서 삿대 가져와라
# : 부정
# 독 웃 먼저하고 영상 시청합니다 오래전 구독했는데 다시 구독 표시가 뜨네요
# : 긍정
# 크 역시
# : 긍정
# 주제도 좋고 배우들 연기도 좋은데 중간중간 나오는 가 너무 처참해서 몰입을 깬다
# : 부정
# 하나의 민초는 약하지만 여럿이 모이면 어떤 나무보다도 강하고 그 어떤 무엇도 막을 수 없다 참으로 이상한 나라지 평소에는 이기적이지만 힘들 때 만큼은 모두가 한 마음 한 뜻을 이루는 나라 대한민국만이 가능한게 아닐까라고 생각이 듭니다
# : 긍정
# 바다를 버리는것은 조선을 버리는것과 같다 이순신이 척의 배를 끌고 나갈수 밖에 없었던 이유
# : 긍정
# 벡업타이밍 나이스
# : 긍정
# 한국영화사의 흑역사 성웅을 다룬 영화에 이런 저급 신파를
# : 부정
# 생각해보면 세기 유럽의 아메리카 식민지랑 같은 형국으로 지금 쯤이면 문화도 말도 다 바뀌어있어도 이상하지 않을 이 쪼그만한 나라가 당시 유럽처럼 해군전력이 막강한 일본한테 지금까지 절대 굴복안함
# : 긍정
# 군인의로써 내가 가장 존경하는 분 이순신장군님
# : 긍정
# 네가 가장존경하는 위인은 세종대왕과 이순신이고 앞으로도 가장존경하는 위인은 세종대왕과 이순신장군님이다
# : 긍정
# 어우 일본인들 머리스타일 진짜 이상하다 모자란거같음
# : 부정
# 되겠느냐
# : 부정
# 국뽕 다다다다다다다다
# : 부정
# 우와 정말 시간을달리는 구나
# : 부정
# 혼자서 버틴 그 시간 내뺄 생각 뿐이던 부하 배들을 피가 끓어 모이게 하고 일본군을 질리게 만들어버린 그 시간 오직 이순신만이 버텨낼 수 있던 그 시간은 전쟁사에도 역사 전체에도 길이 남을 최고의 순간입니다
# : 긍정
# 진짜 국뽕 만배다
# : 부정
# 내가 너 좋아하면 안되냐 내가 너 좋아할수도있잖아 그래 안그래
# : 부정
# 김명민 배우의 이순신도 최민식 배우의 이순신도 너무 멋졌다
# : 긍정
# 플래그
# : 부정
# 이순신 살고싶어서 죽었네
# : 긍정
# 대단하다
# : 긍정
# 감동입니다 이신신만새
# : 긍정
# 달동안 고쳐서 대임
# : 부정
# 척인데 그게 베틀쿠루져였어
# : 부정
# 국뽕이 차오른다 가즈아 국뽕이 차오른다 가즈아
# : 부정
# 구례에 가면 수군재건공원이 있는데 칠천량 해전 이후 이순신이 다시 통제사에 복직되면서 병력을 소집하니 명이었다고 합니다
# : 긍정
# 꾸
# : 부정
# 와
# : 긍정
# 시거렁들이머시옼웃키네
# : 긍정
# 가토 기요마사인가요
# : 부정
# 진짜 이레서 내가 이순신장군님을 존경하잖아
# : 긍정
# 한국사에서 부동의 원탑 이순신은 하늘이 내려준 성군임 말도 안되는 수준으로 조선을 구한 여튼 이순신장군에 대해 더 공부해보면 그냥 인간이 아닌 수준임 강감찬 광개토대왕 을지문덕 절대 비빌수가 없는 전쟁의 신이 이순신 장군님임
# : 긍정
# 초 진짜 멋있다
# : 긍정
# 초에 장수 뒤에 일본군사 넌 왜살아있는데
# : 긍정
# 소설도 이렇게 쓰면 비현실적이라 욕먹을텐데 대단하면서도 감사합니다
# : 긍정
# 썅도문디들이 피눈물 흘리는 영상
# : 긍정
# 국뽕이 차오르는구나
# : 부정
# 나라와 인생의 위기에서 자신을 믿고 따르는 군사들을 지휘하는 장수의 마음이 어찌 할지 상상도 하기 힘듭니다 최민식 배우의 혼신이 느껴집니다 감사합니다
# : 긍정
# 나는 이 영화에서 스님이 왜 장창 한자루 가지고 저렇게 센 캐릭터로 나왔는지 모르고 있었다 그러나 한국사를 배우게 되고 의병장만이 아닌 승병장들의 활약이 대단했던 거에 비하면 영화에 나온 장창도 부족하단 느낌이 들었다 정말 고맙습니다 유교국가에서 조국을 의해 목숨바친 불교이기에 불자는 아니지만 불교를 칭찬합니다
# : 긍정
# 저와중에 한걸음 빠진정도가 아니라 네임드 하나 튀려다가 군법소리 오고갔지
# : 부정
# 국뽕 차오른다
# : 부정
# 갠적으로 젤 좋아하던 장면 끌어주는게 너무 감동이였음 손에 피 엄청 나는데도 끌어주는게
# : 긍정
# 이순신 아녔으면 우린 이 언어를 사용하지 않았을것이다
# : 긍정
# 그냥 우리나라역사자체가 세계 유네스코에 등재돼야함 진짜
# : 부정
# 치맛바람타고 왔네
# : 부정
# 천운
# : 부정
# 일본인은 우리나라에 안되안되 인본인 듸져라
# : 긍정
# 성웅 이순신장군을 화폐에 다시 넣어야한다 신사임당 이이 이황은 시대에 맞지 않는다고 생각한다
# : 긍정
# 보는 내내 소름이 돋아서 닭이 된채로 보았습니다 사랑하고 존경합니다 이순신장군님
# : 긍정
# 일본양아치들아 독도넘보다가는니들은 좃되는거다 와라 이처럼 처참히 부셔버릴테니
# : 부정
# 졸라 지루해서 중간에 나갔다는 돈 아까워
# : 부정
# 실제 명량은 해류를 활용해서 적이 근접못할때 사거리 우위를 활용해 포격전으로 몰살했다는 식으로 알고있습니다
# : 부정
# 난중일기 보면 전라도 군사들이 하도 말을 안들어서 매일같이 사형시키는 것이 나오지요 장군님은 이게 더 힘듦
# : 긍정
# 갠적으로는 별로
# : 부정
# 꾹뽕 이 차오른다
# : 부정
# 슈퍼히어로랜딩
# : 부정
# 어째 우리나라만 이렇게 이긴 전쟁이 많냐
# : 부정
# 으
# : 부정
# 가슴이 웅 장해 진다
# : 긍정
# 월도 좆간지다
# : 긍정
# 지금이 어떻던 간에 우리 민족이 피땀흘려 지킨 땅이다
# : 긍정
# 방금 보고옴 이순신 정말 대단하다고 다시느끼네
# : 긍정
# 실제 기록에선 이순신 대장선에선 뛰어내려 실종된 명말곤 전사자가 없고 일본배들은 거의 이순신 대장선을 건들지조차 못했다는데 영화라 하향먹인것
# : 부정
# 대사들이 오글거려서 그렇지 판옥선 돌격할 때 도깨비 돌기 솓은 거는 멋짐
# : 부정
# 마음이 편하게 살살 녹누
# : 긍정
# 이런분들이 나라를 위해 용기내서 싸워주고 이겨냈으니 지금 편하게 사는게 아닐까 싶다 감사합니다
# : 긍정
# 울돌목을 넘 쉽게봤구만
# : 긍정
# 와우 폭탄 날아가는거 잘 만들었네요 최고
# : 긍정
# 도요툐미 히데요시 및 와키자카 요스하루를 죽이고서 나도 죽겠다 그놈들은 꼭 죽일것이다
# : 부정
# 주의 이영상에는 국뽕이 과다 함유되어있습니다
# : 부정
# 실제로는 두명밖에 안 죽었다는
# : 부정
# 이 영화는 캐스팅 미스지 솔직히 최민식이 이순신 역할에 어울리냐
# : 부정
# 사실상 척 척임 척은 도망갔으니
# : 부정
# 등
# : 부정
# 배설장군아니었으면 척배가지고 저런승리고 못했을듯 이순신만의 공이 아님
# : 부정
# 참고 저 영화에서 이순신 너프먹음
# : 긍정
# 이지스함 척
# : 부정
# 이순신 한정 김명민 미만잡이다
# : 긍정
# 대한민국 진짜 영웅이 많은 나라다
# : 긍정
# 이순신장군님 화살에 맞는분은 감사할줄알아라 그만큼 위대한역사를이룬 분이시다
# : 긍정
# 우리민족은 이순신장군님 아니였으면 멸족당했습니다
# : 긍정
# 대사나 연출력이나 촌스러운게 참 김한민답다
# : 부정
# 우리가 똑똑한게 아니고 일본놈들이 바보인거임
# : 긍정
# 국뽕
# : 부정
# 여지까지 이순신 장군님 계셨으면 맥아더 장군 빰치는 수준이였을텐데 진짜 대단하다
# : 긍정
# 중간에 안나온 장면도 많은디 편집을 맛갈나게해서 하말이 읍다
# : 부정
# 항상 감사하며 살겠습니다 이순신장군 외 참전 용사분들
# : 긍정
# 대장선을 버리고 빤스런 하는 척의 배도 우리 민족의 뼈아픈 현실
# : 긍정
# 한국에는 구세주가 명 있음 때 전쟁에 참여하신 미군분들 이순신 장군
# : 긍정
# 우리나라를 건드린 옛날 일본왕의 최 후 꼴 좋다
# : 부정
# 이순신이 넘 뚱하다 불멸의 이순신이 최고지
# : 긍정
# 동해 물과백두산이
# : 부정
# 이순신 장군 님너무멋이어요
# : 긍정
# 화살 눈에 꽃히는거 왤케 속시원하지
# : 부정
# 그 아까 일은예 제가 정식으로 사과드 리 겠 습 니 다
# : 부정
# 목소리
# : 부정
# 이순신장군님장하시다
# : 긍정
# 조란탄 기겁하겠네 어휴
# : 부정
# 일본 들 조선시대에도 민폐 근대에도 민폐 우리에게 단 한번도 도움이 된 적 없는 영원한 암덩어리
# : 부정
# 이순신 장군이 없었어면 아마도 지금 광화문광장 에 토요토미 히데요시 동상이 있지 않았을까
# : 긍정
# 이 영화는 사상의 문제가 아니고 진짜 대한민국 큰 의미를 가지는 영화라고 생각됨 지금 나이드신 분들이 어릴때 보던 그 임진왜란 영화들을 뛰어넘은
# : 긍정
# 맨정신도아니고 아들잃고 부모님아프시고 본인은 좆같은 선조새끼때문에 고생이란고생다하셔놓고 심지어 출전하시기전에 몸도아프셔서 앓으셨고 식사또한 소금밥과 소량의 물 최악의조건에서 전술적 위치를 포기하고 공포심에 이탈자들이 속출하고 실제 난중일기를보면 도망가려고 꾀를 쓰는모습들이 보인다고 서술되어있습니다 이러한 상황속에 단 열두척의 배로 보통사람이라면 선조목을따고 일본에넘어가지않을까 싶을정도로 조선의 왕은 자신을 버렸지만 이순신 장군님은 조선을 버리지않으셨습니
# : 부정
# 일본은 결코 우릴 이길 수가 없음 현재도
# : 긍정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정
#
# : 부정

# %%
reviews = df.iloc[0].to_list()

for sen in reviews:
  sent_cnn.predict(sen)
# Out:
# 이순신장군님 감사합니다
# : 긍정
# 부에서 밝혀지는 진선규의 비밀은 극한직업 부
# : 긍정
# 모르겟다 난 갠적으로 주지훈도 눈물연기가 내느낌으론 진짜 찐으로 울컥해서 눈물이 난거같이서 진짜 슬픈장면이엇다 생각함
# : 긍정
# 울었으면 웃으러 가자
# : 긍정
# 마블팬들에게 가슴을 울리게한 장면
# : 긍정
# 오늘 소개한 영화 아바타는 국내 관객 만을 기록하기도 했으며 전세계 박스오피스 위를 년간 지켰던 명작인데요 어벤져스 엔드게임 개봉 당시 잠시 위 자리를 빼앗기기도 했었지만 최근 코로나로 인한 재개봉으로 인해 엔드게임을 제치고 다시 위에 올라 섰다고 합니다 하지만 차이가 크지 않기 때문에 엔드게임도 재개봉을 하게 된다면 다시 위 자리를 탈환할 수도 있다고하네요 오늘도 시청해주셔서 감사드리고 행복한 하루 보내세요
# : 긍정
# 둘다 글러브 꼈으면 황정민이 이겼다
# : 부정
# 봉준호 감독님은 천재인듯
# : 긍정
# 도둑들 은 왓챠에서 감상 가능합니다 전지현 특별전 다음 전지현 특별전 을 장식할 영화는 어떤 영화일까요 기대해주세요 감사합니다
# : 긍정
# 이거한번더보고싶어서찾아보니있어서 한번더 눈물 콧물 쏟고갑니다 부녀간의사랑이 많이느껴져서
# : 긍정
# 썸네일 전지현 미친듯이 예쁘다
# : 긍정
# 근데 지니가 자유가되게해달랫지 사람이되게해달라고는안했는뎅
# : 부정
# 여캠들 수위가 진짜 고 티 가 지리긴하지
# : 부정
# 왕의 남자 광대 노릇 하지 마라
# : 부정
# 원활한 이해를 위해서는 첫번째 이야기를 보고 오시는게 좋아요 첫번째 이야기
# : 긍정
# 마지막에 아저씨 아내도 있도 아이도 있는데
# : 긍정
# 여러분 북한은 주적입니다
# : 부정
# 진짜 부산행 처음 봤을때 공유 무서웠는데 공유 그 장면 보고 울었는데
# : 긍정
# 줄 착각해서 이민기 앞에 매달린 사람이 떨어졌어야
# : 부정
# 윤석열 한동훈 보고 있나
# : 부정
# 나간다 엄호해봐
# : 부정
# 화질 개구리네
# : 부정
# 이 영상의 모든 수익은 원작자에게 돌아갑니다
# : 긍정
# 진짜 시바 존나 재미있으
# : 긍정

# %% [markdown]
# ---
